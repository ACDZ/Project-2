# %% [markdown]
# # Dummifying and combined cleaning

# %%
import pandas as pd
import numpy as np
import seaborn as sns


# Set random seed.
np.random.seed(42)


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
df_train = pd.read_csv("../data/train_cleaned_no_dummies.csv")
df_test = pd.read_csv("../data/test_cleaned_no_dummies.csv")

# %%
# setting display options so that I can see all column
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 3000)

# %%
df_train.head(3)
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0  533352170           60        RL         55.23     13517   Pave       IR1
# 1  531379050           60        RL         43.00     11492   Pave       IR1
# 2  535304180           20        RL         68.00      7922   Pave       Reg
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 1          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
# 2          Lvl    AllPub     Inside        Gtl        NAmes        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0        Norm      1Fam      2Story             6             8        1976
# 1        Norm      1Fam      2Story             7             5        1996
# 2        Norm      1Fam      1Story             5             7        1953
#
#    Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# 0            2005      Gable   CompShg      HdBoard      Plywood      BrkFace
# 1            1997      Gable   CompShg      VinylSd      VinylSd      BrkFace
# 2            2007      Gable   CompShg      VinylSd      VinylSd         None
#
#    Mas Vnr Area  Exter Qual  Exter Cond Foundation  Bsmt Qual  Bsmt Cond  \
# 0         289.0           4           3     CBlock          3          3
# 1         132.0           4           3      PConc          4          3
# 2           0.0           3           4     CBlock          3          3
#
#   Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  \
# 0            No            GLQ         533.0            Unf           0.0
# 1            No            GLQ         637.0            Unf           0.0
# 2            No            GLQ         731.0            Unf           0.0
#
#    Bsmt Unf SF  Total Bsmt SF Heating  Heating QC Central Air Electrical  \
# 0        192.0          725.0    GasA           5           Y      SBrkr
# 1        276.0          913.0    GasA           5           Y      SBrkr
# 2        326.0         1057.0    GasA           3           Y      SBrkr
#
#    1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# 0         725         754                0         1479             0.0
# 1         913        1209                0         2122             1.0
# 2        1057           0                0         1057             1.0
#
#    Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# 0             0.0          2          1              3              1
# 1             0.0          2          1              4              1
# 2             0.0          1          0              3              1
#
#    Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  Fireplace Qu  \
# 0             4              6        Typ           0             0
# 1             4              8        Typ           1             3
# 2             4              5        Typ           0             0
#
#   Garage Type  Garage Yr Blt Garage Finish  Garage Cars  Garage Area  \
# 0      Attchd         1976.0           RFn          2.0        475.0
# 1      Attchd         1997.0           RFn          2.0        559.0
# 2      Detchd         1953.0           Unf          1.0        246.0
#
#    Garage Qual  Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  \
# 0            3            3           Y             0             44
# 1            3            3           Y             0             74
# 2            3            3           Y             0             52
#
#    Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area  Misc Val  Mo Sold  \
# 0               0           0             0          0         0        3
# 1               0           0             0          0         0        4
# 2               0           0             0          0         0        1
#
#    Yr Sold Sale Type  SalePrice  age
# 0     2010       WD      130500   34
# 1     2009       WD      220000   13
# 2     2010       WD      109000   57

# %%
#Dummifying non-ordinal variables
df_train = pd.get_dummies(df_train, columns=["MS Zoning", "Street", 'Land Contour','Lot Config', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style','Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'Heating', 'Central Air', 'Garage Type', 'Sale Type',
                                               "Lot Shape", "Utilities", "Land Slope", "Bsmt Exposure", "BsmtFin Type 1", "BsmtFin Type 2", "Electrical", "Functional", "Garage Finish", "Paved Drive"])

# %%
df_train.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2027 entries, 0 to 2026
# Data columns (total 246 columns):
#  #    Column                Dtype
# ---   ------                -----
#  0    PID                   int64
#  1    MS SubClass           int64
#  2    Lot Frontage          float64
#  3    Lot Area              int64
#  4    Overall Qual          int64
#  5    Overall Cond          int64
#  6    Year Built            int64
#  7    Year Remod/Add        int64
#  8    Mas Vnr Area          float64
#  9    Exter Qual            int64
#  10   Exter Cond            int64
#  11   Bsmt Qual             int64
#  12   Bsmt Cond             int64
#  13   BsmtFin SF 1          float64
#  14   BsmtFin SF 2          float64
#  15   Bsmt Unf SF           float64
#  16   Total Bsmt SF         float64
#  17   Heating QC            int64
#  18   1st Flr SF            int64
#  19   2nd Flr SF            int64
#  20   Low Qual Fin SF       int64
#  21   Gr Liv Area           int64
#  22   Bsmt Full Bath        float64
#  23   Bsmt Half Bath        float64
#  24   Full Bath             int64
#  25   Half Bath             int64
#  26   Bedroom AbvGr         int64
#  27   Kitchen AbvGr         int64
#  28   Kitchen Qual          int64
#  29   TotRms AbvGrd         int64
#  30   Fireplaces            int64
#  31   Fireplace Qu          int64
#  32   Garage Yr Blt         float64
#  33   Garage Cars           float64
#  34   Garage Area           float64
#  35   Garage Qual           int64
#  36   Garage Cond           int64
#  37   Wood Deck SF          int64
#  38   Open Porch SF         int64
#  39   Enclosed Porch        int64
#  40   3Ssn Porch            int64
#  41   Screen Porch          int64
#  42   Pool Area             int64
#  43   Misc Val              int64
#  44   Mo Sold               int64
#  45   Yr Sold               int64
#  46   SalePrice             int64
#  47   age                   int64
#  48   MS Zoning_A (agr)     uint8
#  49   MS Zoning_C (all)     uint8
#  50   MS Zoning_FV          uint8
#  51   MS Zoning_I (all)     uint8
#  52   MS Zoning_RH          uint8
#  53   MS Zoning_RL          uint8
#  54   MS Zoning_RM          uint8
#  55   Street_Grvl           uint8
#  56   Street_Pave           uint8
#  57   Land Contour_Bnk      uint8
#  58   Land Contour_HLS      uint8
#  59   Land Contour_Low      uint8
#  60   Land Contour_Lvl      uint8
#  61   Lot Config_Corner     uint8
#  62   Lot Config_CulDSac    uint8
#  63   Lot Config_FR2        uint8
#  64   Lot Config_FR3        uint8
#  65   Lot Config_Inside     uint8
#  66   Neighborhood_Blmngtn  uint8
#  67   Neighborhood_Blueste  uint8
#  68   Neighborhood_BrDale   uint8
#  69   Neighborhood_BrkSide  uint8
#  70   Neighborhood_ClearCr  uint8
#  71   Neighborhood_CollgCr  uint8
#  72   Neighborhood_Crawfor  uint8
#  73   Neighborhood_Edwards  uint8
#  74   Neighborhood_Gilbert  uint8
#  75   Neighborhood_Greens   uint8
#  76   Neighborhood_GrnHill  uint8
#  77   Neighborhood_IDOTRR   uint8
#  78   Neighborhood_Landmrk  uint8
#  79   Neighborhood_MeadowV  uint8
#  80   Neighborhood_Mitchel  uint8
#  81   Neighborhood_NAmes    uint8
#  82   Neighborhood_NPkVill  uint8
#  83   Neighborhood_NWAmes   uint8
#  84   Neighborhood_NoRidge  uint8
#  85   Neighborhood_NridgHt  uint8
#  86   Neighborhood_OldTown  uint8
#  87   Neighborhood_SWISU    uint8
#  88   Neighborhood_Sawyer   uint8
#  89   Neighborhood_SawyerW  uint8
#  90   Neighborhood_Somerst  uint8
#  91   Neighborhood_StoneBr  uint8
#  92   Neighborhood_Timber   uint8
#  93   Neighborhood_Veenker  uint8
#  94   Condition 1_Artery    uint8
#  95   Condition 1_Feedr     uint8
#  96   Condition 1_Norm      uint8
#  97   Condition 1_PosA      uint8
#  98   Condition 1_PosN      uint8
#  99   Condition 1_RRAe      uint8
#  100  Condition 1_RRAn      uint8
#  101  Condition 1_RRNe      uint8
#  102  Condition 1_RRNn      uint8
#  103  Condition 2_Artery    uint8
#  104  Condition 2_Feedr     uint8
#  105  Condition 2_Norm      uint8
#  106  Condition 2_PosA      uint8
#  107  Condition 2_PosN      uint8
#  108  Condition 2_RRAe      uint8
#  109  Condition 2_RRAn      uint8
#  110  Condition 2_RRNn      uint8
#  111  Bldg Type_1Fam        uint8
#  112  Bldg Type_2fmCon      uint8
#  113  Bldg Type_Duplex      uint8
#  114  Bldg Type_Twnhs       uint8
#  115  Bldg Type_TwnhsE      uint8
#  116  House Style_1.5Fin    uint8
#  117  House Style_1.5Unf    uint8
#  118  House Style_1Story    uint8
#  119  House Style_2.5Fin    uint8
#  120  House Style_2.5Unf    uint8
#  121  House Style_2Story    uint8
#  122  House Style_SFoyer    uint8
#  123  House Style_SLvl      uint8
#  124  Roof Style_Flat       uint8
#  125  Roof Style_Gable      uint8
#  126  Roof Style_Gambrel    uint8
#  127  Roof Style_Hip        uint8
#  128  Roof Style_Mansard    uint8
#  129  Roof Style_Shed       uint8
#  130  Roof Matl_CompShg     uint8
#  131  Roof Matl_Tar&Grv     uint8
#  132  Roof Matl_WdShake     uint8
#  133  Roof Matl_WdShngl     uint8
#  134  Exterior 1st_AsbShng  uint8
#  135  Exterior 1st_AsphShn  uint8
#  136  Exterior 1st_BrkComm  uint8
#  137  Exterior 1st_BrkFace  uint8
#  138  Exterior 1st_CBlock   uint8
#  139  Exterior 1st_CemntBd  uint8
#  140  Exterior 1st_HdBoard  uint8
#  141  Exterior 1st_ImStucc  uint8
#  142  Exterior 1st_MetalSd  uint8
#  143  Exterior 1st_Plywood  uint8
#  144  Exterior 1st_Stone    uint8
#  145  Exterior 1st_Stucco   uint8
#  146  Exterior 1st_VinylSd  uint8
#  147  Exterior 1st_Wd Sdng  uint8
#  148  Exterior 1st_WdShing  uint8
#  149  Exterior 2nd_AsbShng  uint8
#  150  Exterior 2nd_AsphShn  uint8
#  151  Exterior 2nd_Brk Cmn  uint8
#  152  Exterior 2nd_BrkFace  uint8
#  153  Exterior 2nd_CBlock   uint8
#  154  Exterior 2nd_CmentBd  uint8
#  155  Exterior 2nd_HdBoard  uint8
#  156  Exterior 2nd_ImStucc  uint8
#  157  Exterior 2nd_MetalSd  uint8
#  158  Exterior 2nd_Plywood  uint8
#  159  Exterior 2nd_Stone    uint8
#  160  Exterior 2nd_Stucco   uint8
#  161  Exterior 2nd_VinylSd  uint8
#  162  Exterior 2nd_Wd Sdng  uint8
#  163  Exterior 2nd_Wd Shng  uint8
#  164  Mas Vnr Type_BrkCmn   uint8
#  165  Mas Vnr Type_BrkFace  uint8
#  166  Mas Vnr Type_None     uint8
#  167  Mas Vnr Type_Stone    uint8
#  168  Foundation_BrkTil     uint8
#  169  Foundation_CBlock     uint8
#  170  Foundation_PConc      uint8
#  171  Foundation_Slab       uint8
#  172  Foundation_Stone      uint8
#  173  Foundation_Wood       uint8
#  174  Heating_GasA          uint8
#  175  Heating_GasW          uint8
#  176  Heating_Grav          uint8
#  177  Heating_OthW          uint8
#  178  Heating_Wall          uint8
#  179  Central Air_N         uint8
#  180  Central Air_Y         uint8
#  181  Garage Type_2Types    uint8
#  182  Garage Type_Attchd    uint8
#  183  Garage Type_Basment   uint8
#  184  Garage Type_BuiltIn   uint8
#  185  Garage Type_CarPort   uint8
#  186  Garage Type_Detchd    uint8
#  187  Garage Type_None      uint8
#  188  Sale Type_COD         uint8
#  189  Sale Type_CWD         uint8
#  190  Sale Type_Con         uint8
#  191  Sale Type_ConLD       uint8
#  192  Sale Type_ConLI       uint8
#  193  Sale Type_ConLw       uint8
#  194  Sale Type_New         uint8
#  195  Sale Type_Oth         uint8
#  196  Sale Type_WD          uint8
#  197  Lot Shape_IR1         uint8
#  198  Lot Shape_IR2         uint8
#  199  Lot Shape_IR3         uint8
#  200  Lot Shape_Reg         uint8
#  201  Utilities_AllPub      uint8
#  202  Utilities_NoSeWa      uint8
#  203  Utilities_NoSewr      uint8
#  204  Land Slope_Gtl        uint8
#  205  Land Slope_Mod        uint8
#  206  Land Slope_Sev        uint8
#  207  Bsmt Exposure_Av      uint8
#  208  Bsmt Exposure_Gd      uint8
#  209  Bsmt Exposure_Mn      uint8
#  210  Bsmt Exposure_No      uint8
#  211  Bsmt Exposure_None    uint8
#  212  BsmtFin Type 1_ALQ    uint8
#  213  BsmtFin Type 1_BLQ    uint8
#  214  BsmtFin Type 1_GLQ    uint8
#  215  BsmtFin Type 1_LwQ    uint8
#  216  BsmtFin Type 1_None   uint8
#  217  BsmtFin Type 1_Rec    uint8
#  218  BsmtFin Type 1_Unf    uint8
#  219  BsmtFin Type 2_ALQ    uint8
#  220  BsmtFin Type 2_BLQ    uint8
#  221  BsmtFin Type 2_GLQ    uint8
#  222  BsmtFin Type 2_LwQ    uint8
#  223  BsmtFin Type 2_None   uint8
#  224  BsmtFin Type 2_Rec    uint8
#  225  BsmtFin Type 2_Unf    uint8
#  226  Electrical_FuseA      uint8
#  227  Electrical_FuseF      uint8
#  228  Electrical_FuseP      uint8
#  229  Electrical_Mix        uint8
#  230  Electrical_SBrkr      uint8
#  231  Functional_Maj1       uint8
#  232  Functional_Maj2       uint8
#  233  Functional_Min1       uint8
#  234  Functional_Min2       uint8
#  235  Functional_Mod        uint8
#  236  Functional_Sal        uint8
#  237  Functional_Sev        uint8
#  238  Functional_Typ        uint8
#  239  Garage Finish_Fin     uint8
#  240  Garage Finish_None    uint8
#  241  Garage Finish_RFn     uint8
#  242  Garage Finish_Unf     uint8
#  243  Paved Drive_N         uint8
#  244  Paved Drive_P         uint8
#  245  Paved Drive_Y         uint8
# dtypes: float64(11), int64(37), uint8(198)
# memory usage: 1.1 MB

# %%
df_test.head(100)
# Out:
#           PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0   902301120          190        RM          69.0      9142   Pave       Reg
# 1   905108090           90        RL          60.0      9662   Pave       IR1
# 2   528218130           60        RL          58.0     17104   Pave       IR1
# 3   902207150           30        RM          60.0      8520   Pave       Reg
# 4   535105100           20        RL          60.0      9500   Pave       IR1
# 5   923228370          160        RM          21.0      1890   Pave       Reg
# 6   902427150           20        RM          52.0      8516   Pave       Reg
# 7   907202130           20        RL          60.0      9286   Pave       IR1
# 8   533208090          160        FV          39.0      3515   Pave       Reg
# 9   914476010           20        RL          75.0     10125   Pave       Reg
# 10  531452100          120        RL          50.0      7175   Pave       Reg
# 11  903455140           30        RM          60.0      7200   Pave       Reg
# 12  535303050           20        RL          75.0     11310   Pave       Reg
# 13  906230030           90        RL          60.0      7976   Pave       Reg
# 14  903206160           70        RL          69.0     11737   Pave       IR1
# 15  905480180           20        RL          60.0      9060   Pave       Reg
# 16  902128150          190        RM          60.0     10800   Pave       Reg
# 17  905451300           20        RL          68.0      9571   Pave       Reg
# 18  535425040           20        RL          80.0     10800   Pave       Reg
# 19  902330040           70        RM         121.0     17671   Pave       Reg
# 20  905105070           20        RL          60.0      8246   Pave       IR1
# 21  532354160           20        RL          60.0      8499   Pave       IR1
# 22  531451020          120        RL          50.0      8012   Pave       Reg
# 23  906475050           80        RL          60.0     21453   Pave       IR1
# 24  531363010           20        RL          80.0      9605   Pave       Reg
# 25  907227050           20        RL          60.0      7180   Pave       IR1
# 26  535150070           50        RL          60.0     12513   Pave       IR1
# 27  902125020           70        RM          50.0      9000   Pave       Reg
# 28  534425310           85        RL          80.0      8800   Pave       Reg
# 29  534451020           50        RL          51.0      3500   Pave       Reg
# 30  527404150           20        RL          60.0      7340   Pave       IR1
# 31  903458170           30        RM          52.0      6240   Pave       Reg
# 32  902326030           70        RM          65.0     11700   Pave       IR1
# 33  527378020           20        RL          80.0     10000   Pave       Reg
# 34  907196060           20        RL          75.0     11166   Pave       Reg
# 35  528218100           60        RL          58.0     13204   Pave       IR1
# 36  902103090           50        RM          60.0      5520   Pave       Reg
# 37  905228020           20        RL          60.0      9000   Pave       Reg
# 38  535451010           20        RL          74.0      8892   Pave       Reg
# 39  533242080           20        FV          73.0      7321   Pave       IR1
# 40  533210010          160        FV          40.0      3951   Pave       Reg
# 41  528280100           60        RL          60.0     11214   Pave       IR1
# 42  534427140           20        RL          75.0      7388   Pave       Reg
# 43  535351050           20        RL          75.0     14559   Pave       Reg
# 44  916226090          120        RL          46.0      4054   Pave       IR1
# 45  923228150          160        RM          21.0      1533   Pave       Reg
# 46  907196050           60        RL          68.0     11250   Pave       IR1
# 47  531479030           20        RH          60.0      7800   Pave       Reg
# 48  535350040           20        RL          74.0      5868   Pave       Reg
# 49  532377100           20        RL          75.0      7500   Pave       Reg
# 50  902427040           50        RM          52.0      9439   Pave       Reg
# 51  902329030           70        RM          50.0      9000   Pave       Reg
# 52  906380030           20        RL          65.0      9345   Pave       IR1
# 53  903455090           50        RM          60.0      7200   Pave       Reg
# 54  903228070           50        RM          60.0      6000   Pave       Reg
# 55  527403040           20        RL          61.0      7930   Pave       Reg
# 56  903401020           50        RL          60.0      9120   Pave       Reg
# 57  534252040           20        RL          60.0      9503   Pave       Reg
# 58  527375210           20        RL          85.0     11050   Pave       IR1
# 59  907253060           60        RL          60.0     10316   Pave       IR1
# 60  528346050           20        RL         136.0     11675   Pave       IR1
# 61  905200100          190        RL          60.0     12900   Pave       Reg
# 62  905226170           20        RL          85.0     13770   Pave       Reg
# 63  534250335           60        RL          60.0     13355   Pave       IR1
# 64  531450040           60        RL          65.0      7153   Pave       Reg
# 65  528363050           20        RL          60.0     10750   Pave       IR1
# 66  527403120           20        RL          60.0      8125   Pave       IR1
# 67  528174030          120        RL          34.0      3903   Pave       Reg
# 68  908226180           30        RH          70.0      4270   Pave       Reg
# 69  907425015          120        RM          60.0      4426   Pave       Reg
# 70  534451130           30        RL          52.0      5825   Pave       IR1
# 71  528118060           60        RL          59.0     23303   Pave       IR3
# 72  909428180           20        RL          60.0     25485   Pave       IR1
# 73  527165020           80        RL          60.0     10784   Pave       IR1
# 74  527404030           20        RL          60.0      8510   Pave       IR1
# 75  534129080           80        RL          60.0     17871   Pave       IR1
# 76  923202060           20        RL         100.0     21750   Pave       Reg
# 77  535402230           20        RL          77.0      9510   Pave       Reg
# 78  534276290           20        RL          60.0      8339   Pave       IR1
# 79  528150090           20        RL         131.0     14828   Pave       IR1
# 80  907260040           20        RL          70.0      8749   Pave       Reg
# 81  910205120           50        RM          50.0      9140   Pave       Reg
# 82  902305010           70        RM          60.0      3600   Pave       Reg
# 83  908102020           70        RL          67.0      8777   Pave       Reg
# 84  906476030           60        RL          79.0     12798   Pave       IR1
# 85  528108020           20        RL          98.0     12704   Pave       Reg
# 86  907203070           20        RL          68.0      7480   Pave       Reg
# 87  534251030           85        RL          60.0     16500   Pave       Reg
# 88  916326010           20        RL          60.0     16669   Pave       IR1
# 89  535454160           50        RL          60.0      8064   Pave       Reg
# 90  532354070           20        RL          60.0      7758   Pave       IR1
# 91  908275090           50        RL          70.0     11767   Pave       Reg
# 92  902206130           45        RM          50.0      6900   Pave       Reg
# 93  527183030          120        RL          40.0      4671   Pave       IR1
# 94  903225040           50        RM          50.0      6125   Pave       Reg
# 95  902300040           70        RM          53.0      9863   Pave       Reg
# 96  905451330           20        RL          68.0      9571   Pave       Reg
# 97  528181070          120        RL          34.0      4590   Pave       Reg
# 98  531385060           60        RL          65.0      8450   Pave       Reg
# 99  534177230           60        RL          70.0      8400   Pave       Reg
#
#    Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0           Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 1           Lvl    AllPub     Inside        Gtl       Sawyer        Norm
# 2           Lvl    AllPub     Inside        Gtl      Gilbert        Norm
# 3           Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 4           Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 5           Lvl    AllPub     Inside        Gtl      MeadowV        Norm
# 6           Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 7           Lvl    AllPub    CulDSac        Mod      CollgCr        Norm
# 8           Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 9           Lvl    AllPub     Inside        Gtl      Mitchel        Norm
# 10          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
# 11          Lvl    AllPub     Corner        Gtl       IDOTRR        Norm
# 12          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 13          Lvl    AllPub     Inside        Gtl      SawyerW       Feedr
# 14          Bnk    AllPub     Inside        Gtl      BrkSide        Norm
# 15          Lvl    AllPub     Inside        Gtl      Edwards      Artery
# 16          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 17          Lvl    AllPub     Inside        Gtl      Edwards        Norm
# 18          Lvl    AllPub     Inside        Gtl        NAmes        PosA
# 19          Lvl    AllPub     Corner        Gtl      OldTown      Artery
# 20          Lvl    AllPub     Inside        Gtl       Sawyer        Norm
# 21          Lvl    AllPub     Corner        Gtl       Sawyer       Feedr
# 22          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
# 23          Low    AllPub    CulDSac        Sev      ClearCr        Norm
# 24          Lvl    AllPub     Corner        Gtl      SawyerW        Norm
# 25          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 26          Lvl    AllPub        FR2        Gtl        NAmes       Feedr
# 27          Lvl    AllPub     Corner        Gtl      OldTown      Artery
# 28          Lvl    AllPub     Inside        Gtl        NAmes       Feedr
# 29          Lvl    AllPub     Inside        Gtl      BrkSide       Feedr
# 30          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 31          Lvl    AllPub     Inside        Gtl       IDOTRR        Norm
# 32          Lvl    AllPub     Corner        Gtl      OldTown        Norm
# 33          Lvl    AllPub     Inside        Gtl       NWAmes        Norm
# 34          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 35          Lvl    AllPub     Inside        Gtl      Gilbert        RRAn
# 36          Lvl    AllPub     Corner        Gtl      OldTown        Norm
# 37          Lvl    AllPub     Inside        Gtl       Sawyer        Norm
# 38          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 39          Lvl    AllPub     Inside        Gtl      Somerst        Norm
# 40          Lvl    AllPub     Corner        Gtl      Somerst        Norm
# 41          Lvl    AllPub     Corner        Gtl      Gilbert        Norm
# 42          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 43          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 44          Lvl    AllPub     Inside        Gtl       Timber        Norm
# 45          Lvl    AllPub     Inside        Gtl      MeadowV        Norm
# 46          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 47          Lvl    AllPub     Corner        Gtl      SawyerW        Norm
# 48          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 49          Lvl    AllPub     Corner        Gtl       Sawyer       Feedr
# 50          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 51          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 52          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 53          Lvl    AllPub     Corner        Gtl       IDOTRR        Norm
# 54          Lvl    AllPub     Corner        Gtl      BrkSide        Norm
# 55          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 56          Lvl    AllPub     Inside        Gtl      BrkSide        Norm
# 57          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 58          Lvl    AllPub     Corner        Gtl       NWAmes        Norm
# 59          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 60          Lvl    AllPub     Inside        Gtl      NoRidge        Norm
# 61          Lvl    AllPub     Inside        Gtl       Sawyer       Feedr
# 62          Lvl    AllPub     Corner        Gtl       Sawyer       Feedr
# 63          Lvl    AllPub     Inside        Gtl       NWAmes        Norm
# 64          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
# 65          Lvl    AllPub    CulDSac        Gtl      NoRidge        Norm
# 66          Lvl    AllPub     Corner        Gtl        NAmes        Norm
# 67          Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 68          Bnk    AllPub     Inside        Mod      Edwards        Norm
# 69          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 70          Lvl    AllPub     Inside        Gtl      BrkSide        Norm
# 71          Lvl    AllPub    CulDSac        Gtl      NridgHt        Norm
# 72          Lvl    AllPub    CulDSac        Gtl      Crawfor        Norm
# 73          Lvl    AllPub        FR2        Gtl      Gilbert        Norm
# 74          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 75          Lvl    AllPub    CulDSac        Gtl       NWAmes        Norm
# 76          Lvl    AllPub     Inside        Gtl      Mitchel        Norm
# 77          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 78          Lvl    AllPub     Inside        Gtl        NAmes        Norm
# 79          Lvl    AllPub     Corner        Gtl      NridgHt        Norm
# 80          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 81          HLS    AllPub     Inside        Gtl       IDOTRR        Norm
# 82          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 83          Bnk    AllPub     Inside        Gtl      Edwards       Feedr
# 84          HLS    AllPub     Inside        Mod      ClearCr       Feedr
# 85          Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 86          Lvl    AllPub     Inside        Gtl      CollgCr        Norm
# 87          Lvl    AllPub     Inside        Gtl       NWAmes        Norm
# 88          Lvl    AllPub     Corner        Gtl       Timber        Norm
# 89          Lvl    AllPub     Corner        Gtl        NAmes      Artery
# 90          Lvl    AllPub     Corner        Gtl       Sawyer        Norm
# 91          Lvl    AllPub     Inside        Gtl      Edwards        Norm
# 92          Lvl    AllPub     Corner        Gtl      OldTown        Norm
# 93          HLS    AllPub     Inside        Gtl      StoneBr        Norm
# 94          Lvl    AllPub     Inside        Gtl      BrkSide        Norm
# 95          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 96          Lvl    AllPub     Inside        Gtl      Edwards        Norm
# 97          Lvl    AllPub     Inside        Gtl      NridgHt        Norm
# 98          Lvl    AllPub     Inside        Gtl      SawyerW        Norm
# 99          Lvl    AllPub     Inside        Gtl       NWAmes        Norm
#
#    Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0         Norm    2fmCon      2Story             6             8        1910
# 1         Norm    Duplex      1Story             5             4        1977
# 2         Norm      1Fam      2Story             7             5        2006
# 3         Norm      1Fam      1Story             5             6        1923
# 4         Norm      1Fam      1Story             6             5        1963
# 5         Norm    TwnhsE      2Story             4             6        1972
# 6         Norm      1Fam      1Story             4             6        1958
# 7         Norm      1Fam      1Story             5             7        1977
# 8         Norm    TwnhsE      2Story             7             5        2004
# 9         Norm      1Fam      1Story             6             6        1977
# 10        Norm    TwnhsE      1Story             6             5        1991
# 11        Norm      1Fam      1Story             6             7        1925
# 12        Norm      1Fam      1Story             6             5        1954
# 13        Norm    Duplex      2Story             7             5        2000
# 14        Norm      1Fam      2Story             6             7        1924
# 15        Norm      1Fam      1Story             5             6        1957
# 79        Norm      1Fam      1Story             9             5        2004
# 80        Norm      1Fam      1Story             7             5        2002
# 81        Norm      1Fam      1.5Fin             6             5        1921
# 82        Norm      1Fam      2Story             5             7        1930
# 83        Norm      1Fam      2Story             4             6        1910
# 84        Norm      1Fam      2Story             6             5        1997
# 85        Norm      1Fam      1Story             8             5        2008
# 86        Norm      1Fam      1Story             5             6        1972
# 87        Norm      1Fam      SFoyer             6             5        1971
# 88        Norm      1Fam      1Story             8             6        1981
# 89        Norm      1Fam      1.5Fin             6             7        1948
# 90        Norm      1Fam      1Story             5             7        1962
# 91        Norm      1Fam      2Story             4             7        1910
# 92        Norm      1Fam      1.5Fin             6             7        1938
# 93        Norm    TwnhsE      1Story             8             5        1988
# 94        Norm      1Fam      1.5Fin             5             7        1939
# 95        Norm      1Fam      2Story             6             6        1927
# 96        Norm      1Fam      1Story             5             6        1956
# 97        Norm     Twnhs      1Story             8             5        2006
# 98        Norm      1Fam      2Story             6             5        2001
# 99        Norm      1Fam      2Story             8             6        2001
#
#     Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0             1950      Gable   CompShg      AsbShng      AsbShng
# 1             1977      Gable   CompShg      Plywood      Plywood
# 2             2006      Gable   CompShg      VinylSd      VinylSd
# 3             2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4             1963      Gable   CompShg      Plywood      Plywood
# 5             1972      Gable   CompShg      CemntBd      CmentBd
# 6             2006      Gable   CompShg      MetalSd      MetalSd
# 7             1989      Gable   CompShg      HdBoard      Plywood
# 8             2004      Gable   CompShg      VinylSd      VinylSd
# 9             1977      Gable   CompShg      Plywood      Plywood
# 10            1991      Gable   CompShg      Plywood      Plywood
# 11            1992      Gable   CompShg      VinylSd      VinylSd
# 12            1954        Hip   CompShg      Wd Sdng      BrkFace
# 13            2000        Hip   CompShg      VinylSd      VinylSd
# 14            1996    Gambrel   CompShg      BrkComm       Stucco
# 15            2006        Hip   CompShg      Wd Sdng      Wd Sdng
# 16            1950      Gable   CompShg      Wd Sdng      Wd Sdng
# 17            1956        Hip   CompShg      MetalSd      MetalSd
# 18            1992      Gable   CompShg      HdBoard      HdBoard
# 19            1986      Gable   CompShg      Wd Sdng      Wd Sdng
# 20            2001      Gable   CompShg      Plywood      Plywood
# 21            1961      Gable   CompShg      MetalSd      MetalSd
# 22            1994      Gable   CompShg      Plywood      Plywood
# 23            1969       Flat     Metal      Plywood      Plywood
# 24            2007      Gable   CompShg      VinylSd      VinylSd
# 25            1972        Hip   CompShg      HdBoard      HdBoard
# 26            2007      Gable   CompShg      VinylSd      VinylSd
# 27            1991      Gable   CompShg      VinylSd      VinylSd
# 28            1963      Gable   CompShg      MetalSd      MetalSd
# 29            1950      Gable   CompShg      MetalSd      MetalSd
# 30            1971      Gable   CompShg      HdBoard      HdBoard
# 31            1950      Gable   CompShg      MetalSd      MetalSd
# 32            2003    Mansard   CompShg       Stucco       Stucco
# 33            2000      Gable   CompShg      HdBoard      HdBoard
# 34            2001      Gable   CompShg      VinylSd      VinylSd
# 35            2007      Gable   CompShg      VinylSd      VinylSd
# 36            1980      Gable   CompShg      Wd Sdng      Wd Sdng
# 37            1950      Gable   CompShg      Wd Sdng      Wd Sdng
# 38            1996      Gable   CompShg      WdShing      Wd Shng
# 39            2000      Gable   CompShg      CemntBd      CmentBd
# 40            2009      Gable   CompShg      VinylSd      VinylSd
# 41            1999      Gable   CompShg      VinylSd      VinylSd
# 42            2002      Gable   CompShg      MetalSd      MetalSd
# 43            2000        Hip   CompShg      Wd Sdng      Wd Sdng
# 44            1987      Gable   CompShg      VinylSd      VinylSd
# 45            2008      Gable   CompShg      CemntBd      CmentBd
# 46            2002      Gable   CompShg      VinylSd      VinylSd
# 47            1965      Gable   CompShg      VinylSd      VinylSd
# 48            2000      Gable   CompShg      MetalSd      MetalSd
# 49            1963      Gable   CompShg      HdBoard      HdBoard
# 50            1950      Gable   CompShg      Wd Sdng      Wd Sdng
# 51            2002      Gable   CompShg      Wd Sdng      Wd Sdng
# 52            2007      Gable   CompShg      VinylSd      VinylSd
# 53            1995      Gable   CompShg      Wd Sdng      Wd Sdng
# 54            1950      Gable   CompShg       Stucco       Stucco
# 55            2005      Gable   CompShg      Plywood      Plywood
# 56            1950      Gable   CompShg      Wd Sdng      Wd Sdng
# 57            1983        Hip   CompShg      HdBoard      HdBoard
# 58            1975      Gable   CompShg      Plywood      Plywood
# 59            2000      Gable   CompShg      VinylSd      VinylSd
# 60            1998      Gable   CompShg      VinylSd      VinylSd
# 61            1950      Gable   CompShg      BrkFace       Stucco
# 62            1998      Gable   CompShg      Plywood      Plywood
# 63            1971      Gable   CompShg      HdBoard      HdBoard
# 64            1992      Gable   CompShg      VinylSd      VinylSd
# 65            1995        Hip   CompShg      Wd Sdng      Wd Sdng
# 66            1971      Gable   CompShg      HdBoard      HdBoard
# 67            2006      Gable   CompShg      VinylSd      VinylSd
# 68            2006      Gable   CompShg      MetalSd      MetalSd
# 69            2004      Gable   CompShg      VinylSd      VinylSd
# 70            1953      Gable   CompShg      MetalSd      MetalSd
# 71            2007      Gable   CompShg      VinylSd      VinylSd
# 72            1960      Gable   CompShg      Wd Sdng      MetalSd
# 73            1992      Gable   CompShg      HdBoard      HdBoard
# 74            1971      Gable   CompShg      Plywood      Plywood
# 75            1976      Gable   CompShg      HdBoard      HdBoard
# 76            2006        Hip   CompShg      HdBoard      HdBoard
# 77            1985      Gable   CompShg      HdBoard      HdBoard
# 78            1959      Gable   CompShg      MetalSd      MetalSd
# 79            2005        Hip   CompShg      MetalSd      MetalSd
# 80            2002      Gable   CompShg      VinylSd      VinylSd
# 81            1975      Gable   CompShg      Wd Sdng      Wd Sdng
# 82            2005    Gambrel   CompShg      VinylSd      VinylSd
# 83            2000      Gable   CompShg      Plywood      Plywood
# 84            1997      Gable   CompShg      VinylSd      VinylSd
# 85            2009        Hip   CompShg      VinylSd      VinylSd
# 86            1972      Gable   CompShg      Wd Sdng      Wd Sdng
# 87            1971        Hip   CompShg      HdBoard      HdBoard
# 88            1981        Hip   WdShake      Plywood      Plywood
# 89            1994      Gable   CompShg      MetalSd      MetalSd
# 90            2001      Gable   CompShg      HdBoard      Plywood
# 52             30               0           0             0          0
# 53             65             190           0             0          0
# 54              0              98           0             0          0
# 55             48               0           0             0          0
# 56            100               0           0             0          0
# 57             28               0           0             0          0
# 58              0               0           0             0          0
# 59            184               0           0             0          0
# 60             33               0           0             0          0
# 61              0             190           0             0          0
# 62              0               0           0             0          0
# 63              0               0           0             0          0
# 64            124               0           0             0          0
# 65             56               0           0             0          0
# 66              0               0           0             0          0
# 67             50               0           0             0          0
# 68              0             286           0             0          0
# 69              0               0           0             0          0
# 70              0              32           0             0          0
# 71            273               0           0             0          0
# 72             75             584           0             0          0
# 73              0               0           0             0          0
# 74              0               0           0             0          0
# 75              0               0           0             0          0
# 76              0               0           0             0          0
# 77            240               0           0             0          0
# 78              0               0           0             0          0
# 79             68               0           0             0          0
# 80             39               0           0             0          0
# 81             56               0           0           200          0
# 82             32               0           0             0          0
# 83              0               0           0             0          0
# 84            114             185           0             0          0
# 85             90               0           0             0          0
# 86              0               0           0             0          0
# 87             20               0           0             0          0
# 88             64               0           0             0          0
# 89             36               0           0             0          0
# 90            132               0           0             0          0
# 91             24               0           0             0          0
# 92              0               0           0             0          0
# 93            120               0           0             0          0
# 94              0             192           0             0          0
# 95              0               0           0             0          0
# 96              0               0           0           576          0
# 97             73               0           0             0          0
# 98             68               0           0             0          0
# 99             45               0           0             0          0
#
#     Misc Val  Mo Sold  Yr Sold Sale Type  age
# 0          0        4     2006       WD    96
# 1          0        8     2006       WD    29
# 2          0        9     2006       New    0
# 3          0        7     2007       WD    84
# 4          0        7     2009       WD    46
# 5          0        6     2010       WD    38
# 6          0        5     2008       WD    50
# 7          0       10     2009       WD    32
# 8          0        1     2010       WD     6
# 9          0        2     2008       WD    31
# 10         0        6     2006       WD    15
# 11         0        7     2008       WD    83
# 12         0        6     2006       WD    52
# 13         0       10     2009       WD     9
# 14         0        5     2006       WD    82
# 15         0        6     2007       WD    50
# 16         0        5     2008       Con   68
# 17         0        2     2009       WD    53
# 18         0        8     2006       WD    45
# 19         0       11     2009       WD   127
# 20         0        5     2010       WD    42
# 21         0        6     2009       WD    48
# 22         0        7     2008       WD    15
# 23         0       10     2006       WD    37
# 24         0        4     2009       WD     2
# 25         0        5     2008       WD    36
# 26         0        6     2009       WD    89
# 27         0        6     2006       WD   126
# 28         0        5     2010       WD    47
# 29      2000        7     2007       WD    62
# 30         0        6     2007       WD    36
# 31         0        1     2009       WD    84
# 32         0        5     2009       WD   129
# 33         0       11     2008       WD    35
# 34         0        7     2009       WD     8
# 35         0        5     2007       New    1
# 36         0        7     2006       WD    86
# 37         0        5     2007       WD    62
# 38         0       10     2008       WD    55
# 39         0       12     2007       COD    8
# 40         0        6     2009       New    0
# 41         0        7     2006       WD     8
# 42         0        7     2007       WD    48
# 43      2000        6     2009       WD    58
# 44         0       10     2007       WD    20
# 45         0        5     2009       WD    39
# 46         0        9     2008       WD     7
# 47         0        7     2006       WD    41
# 48         0        5     2010       WD    54
# 49         0        6     2010       WD    47
# 50         0        3     2007       WD    77
# 51         0        4     2010       WD   120
# 52         0        5     2008       WD     1
# 53         0        7     2006       WD    68
# 54         0        6     2009       WD    85
# 55         0        7     2009       WD    40
# 56         0        6     2008       WD    83
# 57         0        6     2007       WD    49
# 58         0        8     2009       WD    34
# 59         0        6     2008       WD     8
# 60         0        7     2008       WD    10
# 61         0        1     2008       WD    88
# 62         0       10     2007       VWD   49
# 63         0        5     2008       WD    37
# 64         0        7     2006       WD    14
# 65         0        6     2009       WD    15
# 66         0        6     2006       WD    35
# 67         0        5     2007       WD     2
# 68         0        5     2007       WD    76
# 69         0        5     2008       WD     4
# 70         0        6     2006       WD    80
# 71         0        6     2009       WD     2
# 72         0        5     2007       WD    47
# 73         0        5     2007       WD    16
# 74         0        7     2009       WD    38
# 75         0        6     2009       WD    42
# 76         0       11     2009       WD    49
# 77         0        5     2006       WD    44
# 78      1200        7     2007       WD    48
# 79         0        8     2006       WD     2
# 80         0        9     2007       WD     5
# 81         0        4     2010       COD   89
# 82         0        7     2007       WD    77
# 83       420       10     2006       WD    96
# 84       400        5     2008       WD    11
# 85         0        8     2009       New    1
# 86         0        6     2010       WD    38
# 87         0        5     2009       WD    38
# 88         0        1     2006       WD    25
# 89         0        8     2009       COD   61
# 90         0        3     2007       WD    45
# 91         0        5     2007       WD    97
# 92         0        1     2010       WD    72
# 93         0       10     2008       WD    20
# 94         0        3     2007       CWD   68
# 95         0        3     2007       WD    80
# 96         0        7     2008       WD    52
# 97         0        5     2007       CWD    1
# 98         0        9     2008       WD     7
# 99         0       11     2009       WD     8

# %%
#Dummifying non-ordinal variables
df_test = pd.get_dummies(df_test, columns=["MS Zoning", "Street", 'Land Contour','Lot Config', 'Neighborhood', 'Condition 1', 'Condition 2', 'Bldg Type', 'House Style','Roof Style', 'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type', 'Foundation', 'Heating', 'Central Air', 'Garage Type', 'Sale Type',
                                               "Lot Shape", "Utilities", "Land Slope", "Bsmt Exposure", "BsmtFin Type 1", "BsmtFin Type 2", "Electrical", "Functional", "Garage Finish", "Paved Drive"])

# %%
df_test.info(verbose = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 236 columns):
#  #    Column                Dtype
# ---   ------                -----
#  0    PID                   int64
#  1    MS SubClass           int64
#  2    Lot Frontage          float64
#  3    Lot Area              int64
#  4    Overall Qual          int64
#  5    Overall Cond          int64
#  6    Year Built            int64
#  7    Year Remod/Add        int64
#  8    Mas Vnr Area          float64
#  9    Exter Qual            int64
#  10   Exter Cond            int64
#  11   Bsmt Qual             int64
#  12   Bsmt Cond             int64
#  13   BsmtFin SF 1          int64
#  14   BsmtFin SF 2          int64
#  15   Bsmt Unf SF           int64
#  16   Total Bsmt SF         int64
#  17   Heating QC            int64
#  18   1st Flr SF            int64
#  19   2nd Flr SF            int64
#  20   Low Qual Fin SF       int64
#  21   Gr Liv Area           int64
#  22   Bsmt Full Bath        int64
#  23   Bsmt Half Bath        int64
#  24   Full Bath             int64
#  25   Half Bath             int64
#  26   Bedroom AbvGr         int64
#  27   Kitchen AbvGr         int64
#  28   Kitchen Qual          int64
#  29   TotRms AbvGrd         int64
#  30   Fireplaces            int64
#  31   Fireplace Qu          int64
#  32   Garage Yr Blt         float64
#  33   Garage Cars           int64
#  34   Garage Area           int64
#  35   Garage Qual           int64
#  36   Garage Cond           int64
#  37   Wood Deck SF          int64
#  38   Open Porch SF         int64
#  39   Enclosed Porch        int64
#  40   3Ssn Porch            int64
#  41   Screen Porch          int64
#  42   Pool Area             int64
#  43   Misc Val              int64
#  44   Mo Sold               int64
#  45   Yr Sold               int64
#  46   age                   int64
#  47   MS Zoning_C (all)     uint8
#  48   MS Zoning_FV          uint8
#  49   MS Zoning_I (all)     uint8
#  50   MS Zoning_RH          uint8
#  51   MS Zoning_RL          uint8
#  52   MS Zoning_RM          uint8
#  53   Street_Grvl           uint8
#  54   Street_Pave           uint8
#  55   Land Contour_Bnk      uint8
#  56   Land Contour_HLS      uint8
#  57   Land Contour_Low      uint8
#  58   Land Contour_Lvl      uint8
#  59   Lot Config_Corner     uint8
#  60   Lot Config_CulDSac    uint8
#  61   Lot Config_FR2        uint8
#  62   Lot Config_FR3        uint8
#  63   Lot Config_Inside     uint8
#  64   Neighborhood_Blmngtn  uint8
#  65   Neighborhood_Blueste  uint8
#  66   Neighborhood_BrDale   uint8
#  67   Neighborhood_BrkSide  uint8
#  68   Neighborhood_ClearCr  uint8
#  69   Neighborhood_CollgCr  uint8
#  70   Neighborhood_Crawfor  uint8
#  71   Neighborhood_Edwards  uint8
#  72   Neighborhood_Gilbert  uint8
#  73   Neighborhood_Greens   uint8
#  74   Neighborhood_IDOTRR   uint8
#  75   Neighborhood_MeadowV  uint8
#  76   Neighborhood_Mitchel  uint8
#  77   Neighborhood_NAmes    uint8
#  78   Neighborhood_NPkVill  uint8
#  79   Neighborhood_NWAmes   uint8
#  80   Neighborhood_NoRidge  uint8
#  81   Neighborhood_NridgHt  uint8
#  82   Neighborhood_OldTown  uint8
#  83   Neighborhood_SWISU    uint8
#  84   Neighborhood_Sawyer   uint8
#  85   Neighborhood_SawyerW  uint8
#  86   Neighborhood_Somerst  uint8
#  87   Neighborhood_StoneBr  uint8
#  88   Neighborhood_Timber   uint8
#  89   Neighborhood_Veenker  uint8
#  90   Condition 1_Artery    uint8
#  91   Condition 1_Feedr     uint8
#  92   Condition 1_Norm      uint8
#  93   Condition 1_PosA      uint8
#  94   Condition 1_PosN      uint8
#  95   Condition 1_RRAe      uint8
#  96   Condition 1_RRAn      uint8
#  97   Condition 1_RRNe      uint8
#  98   Condition 1_RRNn      uint8
#  99   Condition 2_Feedr     uint8
#  100  Condition 2_Norm      uint8
#  101  Condition 2_PosA      uint8
#  102  Bldg Type_1Fam        uint8
#  103  Bldg Type_2fmCon      uint8
#  104  Bldg Type_Duplex      uint8
#  105  Bldg Type_Twnhs       uint8
#  106  Bldg Type_TwnhsE      uint8
#  107  House Style_1.5Fin    uint8
#  108  House Style_1.5Unf    uint8
#  109  House Style_1Story    uint8
#  110  House Style_2.5Fin    uint8
#  111  House Style_2.5Unf    uint8
#  112  House Style_2Story    uint8
#  113  House Style_SFoyer    uint8
#  114  House Style_SLvl      uint8
#  115  Roof Style_Flat       uint8
#  116  Roof Style_Gable      uint8
#  117  Roof Style_Gambrel    uint8
#  118  Roof Style_Hip        uint8
#  119  Roof Style_Mansard    uint8
#  120  Roof Style_Shed       uint8
#  121  Roof Matl_CompShg     uint8
#  122  Roof Matl_Metal       uint8
#  123  Roof Matl_Roll        uint8
#  124  Roof Matl_Tar&Grv     uint8
#  125  Roof Matl_WdShake     uint8
#  126  Roof Matl_WdShngl     uint8
#  127  Exterior 1st_AsbShng  uint8
#  128  Exterior 1st_AsphShn  uint8
#  129  Exterior 1st_BrkComm  uint8
#  130  Exterior 1st_BrkFace  uint8
#  131  Exterior 1st_CemntBd  uint8
#  132  Exterior 1st_HdBoard  uint8
#  133  Exterior 1st_MetalSd  uint8
#  134  Exterior 1st_Plywood  uint8
#  135  Exterior 1st_PreCast  uint8
#  136  Exterior 1st_Stucco   uint8
#  137  Exterior 1st_VinylSd  uint8
#  138  Exterior 1st_Wd Sdng  uint8
#  139  Exterior 1st_WdShing  uint8
#  140  Exterior 2nd_AsbShng  uint8
#  141  Exterior 2nd_AsphShn  uint8
#  142  Exterior 2nd_Brk Cmn  uint8
#  143  Exterior 2nd_BrkFace  uint8
#  144  Exterior 2nd_CBlock   uint8
#  145  Exterior 2nd_CmentBd  uint8
#  146  Exterior 2nd_HdBoard  uint8
#  147  Exterior 2nd_ImStucc  uint8
#  148  Exterior 2nd_MetalSd  uint8
#  149  Exterior 2nd_Other    uint8
#  150  Exterior 2nd_Plywood  uint8
#  151  Exterior 2nd_PreCast  uint8
#  152  Exterior 2nd_Stucco   uint8
#  153  Exterior 2nd_VinylSd  uint8
#  154  Exterior 2nd_Wd Sdng  uint8
#  155  Exterior 2nd_Wd Shng  uint8
#  156  Mas Vnr Type_BrkCmn   uint8
#  157  Mas Vnr Type_BrkFace  uint8
#  158  Mas Vnr Type_CBlock   uint8
#  159  Mas Vnr Type_None     uint8
#  160  Mas Vnr Type_Stone    uint8
#  161  Foundation_BrkTil     uint8
#  162  Foundation_CBlock     uint8
#  163  Foundation_PConc      uint8
#  164  Foundation_Slab       uint8
#  165  Foundation_Stone      uint8
#  166  Foundation_Wood       uint8
#  167  Heating_Floor         uint8
#  168  Heating_GasA          uint8
#  169  Heating_GasW          uint8
#  170  Heating_Grav          uint8
#  171  Central Air_N         uint8
#  172  Central Air_Y         uint8
#  173  Garage Type_2Types    uint8
#  174  Garage Type_Attchd    uint8
#  175  Garage Type_Basment   uint8
#  176  Garage Type_BuiltIn   uint8
#  177  Garage Type_CarPort   uint8
#  178  Garage Type_Detchd    uint8
#  179  Garage Type_None      uint8
#  180  Sale Type_COD         uint8
#  181  Sale Type_CWD         uint8
#  182  Sale Type_Con         uint8
#  183  Sale Type_ConLD       uint8
#  184  Sale Type_ConLI       uint8
#  185  Sale Type_ConLw       uint8
#  186  Sale Type_New         uint8
#  187  Sale Type_Oth         uint8
#  188  Sale Type_VWD         uint8
#  189  Sale Type_WD          uint8
#  190  Lot Shape_IR1         uint8
#  191  Lot Shape_IR2         uint8
#  192  Lot Shape_IR3         uint8
#  193  Lot Shape_Reg         uint8
#  194  Utilities_AllPub      uint8
#  195  Utilities_NoSewr      uint8
#  196  Land Slope_Gtl        uint8
#  197  Land Slope_Mod        uint8
#  198  Land Slope_Sev        uint8
#  199  Bsmt Exposure_Av      uint8
#  200  Bsmt Exposure_Gd      uint8
#  201  Bsmt Exposure_Mn      uint8
#  202  Bsmt Exposure_No      uint8
#  203  Bsmt Exposure_None    uint8
#  204  BsmtFin Type 1_ALQ    uint8
#  205  BsmtFin Type 1_BLQ    uint8
#  206  BsmtFin Type 1_GLQ    uint8
#  207  BsmtFin Type 1_LwQ    uint8
#  208  BsmtFin Type 1_None   uint8
#  209  BsmtFin Type 1_Rec    uint8
#  210  BsmtFin Type 1_Unf    uint8
#  211  BsmtFin Type 2_ALQ    uint8
#  212  BsmtFin Type 2_BLQ    uint8
#  213  BsmtFin Type 2_GLQ    uint8
#  214  BsmtFin Type 2_LwQ    uint8
#  215  BsmtFin Type 2_None   uint8
#  216  BsmtFin Type 2_Rec    uint8
#  217  BsmtFin Type 2_Unf    uint8
#  218  Electrical_FuseA      uint8
#  219  Electrical_FuseF      uint8
#  220  Electrical_FuseP      uint8
#  221  Electrical_None       uint8
#  222  Electrical_SBrkr      uint8
#  223  Functional_Maj1       uint8
#  224  Functional_Maj2       uint8
#  225  Functional_Min1       uint8
#  226  Functional_Min2       uint8
#  227  Functional_Mod        uint8
#  228  Functional_Typ        uint8
#  229  Garage Finish_Fin     uint8
#  230  Garage Finish_None    uint8
#  231  Garage Finish_RFn     uint8
#  232  Garage Finish_Unf     uint8
#  233  Paved Drive_N         uint8
#  234  Paved Drive_P         uint8
#  235  Paved Drive_Y         uint8
# dtypes: float64(3), int64(44), uint8(189)
# memory usage: 484.6 KB

# %%
train_cols = list(df_train.columns)
test_cols = list(df_test.columns)

# %%
# check whether columns in train are in test
test_not_in_train = []
for i in train_cols:
    if i not in test_cols:
        test_not_in_train.append(i)
test_not_in_train.remove("SalePrice")
test_not_in_train
# Out:
# ['MS Zoning_A (agr)',
#  'Neighborhood_GrnHill',
#  'Neighborhood_Landmrk',
#  'Condition 2_Artery',
#  'Condition 2_PosN',
#  'Condition 2_RRAe',
#  'Condition 2_RRAn',
#  'Condition 2_RRNn',
#  'Exterior 1st_CBlock',
#  'Exterior 1st_ImStucc',
#  'Exterior 1st_Stone',
#  'Exterior 2nd_Stone',
#  'Heating_OthW',
#  'Heating_Wall',
#  'Utilities_NoSeWa',
#  'Electrical_Mix',
#  'Functional_Sal',
#  'Functional_Sev']

# %%
df_train.drop(labels=test_not_in_train, axis=1, inplace=True)

# %%
# check whether columns in train are in test
train_not_in_test = []
for i in test_cols:
    if i not in train_cols:
        train_not_in_test.append(i)
train_not_in_test
# Out:
# ['Roof Matl_Metal',
#  'Roof Matl_Roll',
#  'Exterior 1st_PreCast',
#  'Exterior 2nd_Other',
#  'Exterior 2nd_PreCast',
#  'Mas Vnr Type_CBlock',
#  'Heating_Floor',
#  'Sale Type_VWD',
#  'Electrical_None']

# %%
df_test.drop(labels=train_not_in_test, axis=1, inplace=True)

# %%
df_train.to_csv('../data/train_dummies_matched.csv', index = False)

# %%
df_test.to_csv('../data/test_dummies_matched.csv', index = False)
