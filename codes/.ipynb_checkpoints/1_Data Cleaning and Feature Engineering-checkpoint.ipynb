# %% [markdown]
# # DSI 23 - Project 2

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# We are a data team of a real estate investment company specifically looking at property based in the middle of the United States.
# The management saw that the returns in Ames, Iowa have been dismal and would like the data team to see if we can help the purchasing team and sales team in Ames.
# After speaking to both the sales and purchasing teams we have come to the conclusion that the purchase teams likes to only buy expensive and new property. There is a human bias chasing after the new and the shiny. Leaving much of the used homes behind.
#
# We would like to see if we can create a model that can predict property prices quite accurately.
# Our model can predict the sale price of properties based on the features of a property unit, and by doing that we can identify properties that are currently sold below market price and add these into our portfolio for a good return on investment.

# %% [markdown]
# ## Background research

# %% [markdown]
# ### Top House Hunting Mistakes:
# from: https://www.investopedia.com/articles/mortgage-real-estate/09/buy-house-emotion-free.asp
# - Price and affordability
# - Mortgage
# - Not shopping around
# - Lacking vision
# - Renovation Costs
# - Neighborhood
#
# ### Most important factors for real estate investing:
# from: https://www.investopedia.com/articles/investing/110614/most-important-factors-investing-real-estate.asp
# - Property location - future developments in the area - look for something with a mid to long term view in mind
# - Valuation of Property
#     - Sales comparison approach: recent comparable sales of properties with similar characteristics—most common and suitable for both new and old properties
#     - Cost approach: the cost of the land and construction, minus depreciation— suitable for new construction
#     - Income approach: based on expected cash inflows—suitable for rentals
# - Investment Purpose and Investment Horizon
#     - Buy and self-use. Here you will save on rent and have the benefit of self-utilization, while also getting value appreciation.
#     - Buy and lease. This offers regular income and long-term value appreciation. However, the temperament to be a landlord is needed to handle possible disputes and legal issues, manage tenants, repair work, etc.
#     - Buy and sell (short-term). This is generally for quick, small to medium profit—the typical property is under construction and sold at a profit on completion.
#     - Buy and sell (long-term). This is generally focused on large intrinsic value appreciation over a long period. This offers alternatives to compliment long-term goals, such as retirement.
# - Overall Real Estate Market
# - Be Careful with Leverage
# - New Construction vs. Existing Property
#     - New construction usually offers attractive pricing, the option to customize, and modern amenities. Risks include delays, increased costs, and the unknowns of a newly developed neighborhood.
#     - Existing properties offer convenience, faster access, established improvements (utilities, landscaping, etc.), and in many cases, lower costs.
#
# - City of Ames
#     https://www.cityofames.org/home/showpublisheddocument/1024/637356764775500000
#
# - Lot Frontage
#     https://www.cityofames.org/home/showdocument?id=35206
#     <img src="../images/ames_frontage_law.png" style="width:500px; height:400px"/>
#
# - Basement Exposure
#     https://demlanghomebuilders.com/understanding-lot-exposures/
#
#     ### Full exposure
#     <img src="../images/full_lot_frontage.png" style="width:350px; height:200px"/>
#
#     ### Half exposure
#     <img src="../images/half_lot_frontage.png" style="width:350px; height:200px"/>
#
#     ### No exposure
#     <img src="../images/no_lot_frontage.png" style="width:350px; height:200px"/>
#
# ### Unfinished Basement
#
# An unfinished basement doesn't mean that the construction process is finished; however, it does mean that the interior space is not a comfortable place to live in or hang out. While an unfinished basement often contains electrical systems, pipes, wires and water heaters, the space can still be used for storage.
#
# https://www.ehow.com/info_12013250_advantages-unfinished-basements.html
#     <img src="../images/unfinished_basement.png" style="width:350px; height:200px"/>
#
#
# ### Ames is a college town
# https://en.wikipedia.org/wiki/Ames,_Iowa
# In 2019, Ames had a population of 66,258.[7] Iowa State University was home to 33,391 students as of fall 2019,[8] which make up approximately one half of the city's population.
#
# Ames also hosts United States Department of Agriculture (USDA) sites: the largest federal animal disease center in the United States, USDA's Agricultural Research Service's National Animal Disease Center (NADC),[9] as well as, one of two national USDA sites for the Animal and Plant Health Inspection Service (APHIS), which comprises the National Veterinary Services Laboratory and the Center for Veterinary Biologics.[10] Ames also hosts the headquarters for the Iowa Department of Transportation.
#
# ### Financial Crisis
# According to the U.S. National Bureau of Economic Research (the official arbiter of U.S. recessions) the recession began in December 2007 and ended in June 2009, and thus extended over eighteen months.[6][23]
# https://en.wikipedia.org/wiki/Great_Recession
#
# ### Owner and Renter stats
# Only 40.7% are owners
# https://worldpopulationreview.com/us-cities/ames-ia-population

# %% [markdown]
# ### Data Cleaning

# %%
# importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer

# Set random seed.
np.random.seed(42)


# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

# %%
# reading training data
raw_df = pd.read_csv("../data/train.csv")

# %%
# setting display options so that I can see all column
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 3000)

# %% [markdown]
# ### Data Dictionary
# http://jse.amstat.org/v19n3/decock/DataDocumentation.txt

# %% [markdown]
# ### Cleaning functions

# %%
def replace_nan_with_none (cols_list):
    for i in cols_list:
        df[i].replace([np.nan], "None", inplace = True)

# %%
def replace_nan_with_zero (list_to_0):
    for i in list_to_0:
        df[i].replace([np.nan], 0, inplace = True)

# %%
def replace_nan_with_none_test (cols_list):
    for i in cols_list:
        df_test[i].replace([np.nan], "None", inplace = True)

# %%
def replace_nan_with_zero_test (list_to_0):
    for i in list_to_0:
        df_test[i].replace([np.nan], 0, inplace = True)

# %% [markdown]
# ### Cleaning

# %%
raw_df.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
# ...

# %%
# df that will be modified and edited as I want to leave a raw df just in case
df = raw_df.copy()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
# ...

# %%
df.isnull().sum().sort_values(ascending = False).head(20)
# Out:
# Pool QC           2042
# Misc Feature      1986
# Alley             1911
# Fence             1651
# Fireplace Qu      1000
# Lot Frontage       330
# Garage Finish      114
# Garage Qual        114
# Garage Yr Blt      114
# Garage Cond        114
# Garage Type        113
# Bsmt Exposure       58
# BsmtFin Type 2      56
# BsmtFin Type 1      55
# Bsmt Cond           55
# Bsmt Qual           55
# Mas Vnr Area        22
# Mas Vnr Type        22
# Bsmt Half Bath       2
# Bsmt Full Bath       2
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %%
#Age of property important

# %%
df["age"] = df["Yr Sold"] - df["Year Built"]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 82 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
# ...

# %% [markdown]
# Before looking further, I would like to reduce the no. of columns for the DF as the number of columns renders the df quite unwieldy.

# %% [markdown]
# ### Splitting the df to 4 segments
#
# As there 81 variables, I will split the df into 20 by 20 by 20 by 21

# %% [markdown]
# #### DATAFRAME 1: COLUMNS 0 - 19

# %%
# Selecting the first 20 columns
df_1  = df.iloc[: , 0:20]

# %%
df_1.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond
# ...

# %%
df_1.isnull().sum().sort_values(ascending = False)
# Out:
# Alley           1911
# Lot Frontage     330
# Id                 0
# Lot Config         0
# Overall Qual       0
# House Style        0
# Bldg Type          0
# Condition 2        0
# Condition 1        0
# Neighborhood       0
# Land Slope         0
# Utilities          0
# PID                0
# Land Contour       0
# Lot Shape          0
# Street             0
# Lot Area           0
# MS Zoning          0
# MS SubClass        0
# Overall Cond       0
# dtype: int64

# %%
# Id is not useful and should be dropped.
# Dropping Id
df.drop(labels=["Id"], axis=1, inplace=True)

# %%
# Looking at the list of null values, Alley is at the top for DF 1
# From the data dictionary, alley is a stand alone variable
# Alley has 93% missing data.
# This variable will be dropped.
df.drop(labels=["Alley"], axis=1, inplace=True)

# %%
# Next is Lot Frontage
df_1["Lot Frontage"].describe()
# Out:
# count    1721.000000
# mean       69.055200
# std        23.260653
# min        21.000000
# 25%        58.000000
# 50%        68.000000
# 75%        80.000000
# max       313.000000
# Name: Lot Frontage, dtype: float64

# %%
# Group lots by configuration
grouped_lots = df.groupby(['Lot Config']).agg({
   'Lot Frontage' : 'mean', 
})
grouped_lots
# Out:
#             Lot Frontage
# Lot Config
# Corner         83.245552
# CulDSac        55.228571
# FR2            60.836735
# FR3            87.000000
# Inside         66.952780

# %%
#replace np.nan with average for lot_config of that type
df.loc[(df['Lot Frontage'].isna()) & (df['Lot Config'] == 'Corner'), 'Lot Frontage'] = 83.25
df.loc[(df['Lot Frontage'].isna()) & (df['Lot Config'] == 'CulDSac'), 'Lot Frontage'] = 55.23        
df.loc[(df['Lot Frontage'].isna()) & (df['Lot Config'] == 'FR2'), 'Lot Frontage'] = 60.84        
df.loc[(df['Lot Frontage'].isna()) & (df['Lot Config'] == 'FR3'), 'Lot Frontage'] = 87.00
df.loc[(df['Lot Frontage'].isna()) & (df['Lot Config'] == 'Inside'), 'Lot Frontage'] = 87.00

# %%
df[df['Lot Frontage'].isnull()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# #### DF 1 Summary
#
# Id dropped
# Alley dropped
# Lot Frontage imputed with mean of the lot configs

# %% [markdown]
# #### DATAFRAME 2: COLUMNS 20 - 39

# %%
# Selecting the next 20 columns
df_2  = df.iloc[: , 20:40]
df_2.head()
# Out:
#   Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  Mas Vnr Area  \
# 0      Gable   CompShg      HdBoard      Plywood      BrkFace         289.0
# 1      Gable   CompShg      VinylSd      VinylSd      BrkFace         132.0
# 2      Gable   CompShg      VinylSd      VinylSd         None           0.0
# 3      Gable   CompShg      VinylSd      VinylSd         None           0.0
# 4      Gable   CompShg      Wd Sdng      Plywood         None           0.0
#
#   Exter Qual Exter Cond Foundation Bsmt Qual Bsmt Cond Bsmt Exposure  \
# 0         Gd         TA     CBlock        TA        TA            No
# 1         Gd         TA      PConc        Gd        TA            No
# 2         TA         Gd     CBlock        TA        TA            No
# 3         TA         TA      PConc        Gd        TA            No
# 4         TA         TA      PConc        Fa        Gd            No
#
#   BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  \
# ...

# %%
df_2.isnull().sum().sort_values(ascending = False)
# Out:
# Bsmt Exposure     58
# BsmtFin Type 2    56
# Bsmt Cond         55
# BsmtFin Type 1    55
# Bsmt Qual         55
# Mas Vnr Type      22
# Mas Vnr Area      22
# Total Bsmt SF      1
# Bsmt Unf SF        1
# BsmtFin SF 2       1
# BsmtFin SF 1       1
# Heating            0
# Roof Style         0
# Roof Matl          0
# Foundation         0
# Exter Cond         0
# Exter Qual         0
# Exterior 2nd       0
# Exterior 1st       0
# Heating QC         0
# dtype: int64

# %% [markdown]
# #### Cleaning basement first

# %%
#As there are also basement variables in df_3, they will be added in here
df2_basement = df[["Bsmt Exposure","BsmtFin Type 1","BsmtFin Type 2","Bsmt Qual","Bsmt Cond","BsmtFin SF 1","BsmtFin SF 2","Bsmt Unf SF","Total Bsmt SF","Bsmt Full Bath","Bsmt Half Bath"]]
df2_basement[df2_basement["Bsmt Exposure"].isna()]
# Out:
#      Bsmt Exposure BsmtFin Type 1 BsmtFin Type 2 Bsmt Qual Bsmt Cond  \
# 12             NaN            NaN            NaN       NaN       NaN
# 93             NaN            NaN            NaN       NaN       NaN
# 114            NaN            NaN            NaN       NaN       NaN
# 146            NaN            NaN            NaN       NaN       NaN
# 183            NaN            NaN            NaN       NaN       NaN
# 240            NaN            NaN            NaN       NaN       NaN
# 249            NaN            NaN            NaN       NaN       NaN
# 256            NaN            NaN            NaN       NaN       NaN
# 390            NaN            NaN            NaN       NaN       NaN
# 437            NaN            NaN            NaN       NaN       NaN
# 485            NaN            NaN            NaN       NaN       NaN
# 499            NaN            NaN            NaN       NaN       NaN
# 514            NaN            NaN            NaN       NaN       NaN
# ...

# %%
df2_bsmt_noexp = df2_basement.loc[(df2_basement['Bsmt Exposure'].isna()) & df2_basement["Total Bsmt SF"] != 0]
df2_bsmt_noexp
# Out:
#      Bsmt Exposure BsmtFin Type 1 BsmtFin Type 2 Bsmt Qual Bsmt Cond  \
# 1456           NaN            Unf            Unf        Gd        TA
# 1547           NaN            Unf            Unf        Gd        TA
# 1997           NaN            Unf            Unf        Gd        TA
#
#       BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  Bsmt Full Bath  \
# 1456           0.0           0.0        725.0          725.0             0.0
# 1547           0.0           0.0       1595.0         1595.0             0.0
# 1997           0.0           0.0        936.0          936.0             0.0
#
#       Bsmt Half Bath
# 1456             0.0
# 1547             0.0
# 1997             0.0

# %%
# Unfinished basements are usually contains electrical systems, pipes, wires and water heaters.
# It does mean that the interior space is not a comfortable place to live in or hang out.
# By logical deduction, since these places are unfinished, it will be not exposed to the public
# As such, the 3 bsmt exposures stated above should be changed to "No"

#get the list of index values where there is basement but NaN for exposure
no_exp = list(df2_bsmt_noexp.index.values)
no_exp
# Out:
# [1456, 1547, 1997]

# %%
# Change NaN at these places to "No"
df.at[no_exp, 'Bsmt Exposure'] = "No"

# %%
df2_bsmt_nabmst = df2_basement.loc[(df2_basement['Bsmt Exposure'].isna()) & (df2_basement["Total Bsmt SF"].isna())]
df2_bsmt_nabmst
# Out:
#      Bsmt Exposure BsmtFin Type 1 BsmtFin Type 2 Bsmt Qual Bsmt Cond  \
# 1327           NaN            NaN            NaN       NaN       NaN
#
#       BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  Bsmt Full Bath  \
# 1327           NaN           NaN          NaN            NaN             NaN
#
#       Bsmt Half Bath
# 1327             NaN

# %%
# this row has null for every bsmt variable and will be removed
na_bmst = list(df2_bsmt_nabmst.index.values)
na_bmst
# Out:
# [1327]

# %%
# Change dropping the all NaN row
df.drop(na_bmst, inplace = True)

# %%
df2_bsmt_nabmst = df2_basement.loc[(df2_basement['Bsmt Full Bath'].isna())]
df2_bsmt_nabmst
# Out:
#      Bsmt Exposure BsmtFin Type 1 BsmtFin Type 2 Bsmt Qual Bsmt Cond  \
# 616            NaN            NaN            NaN       NaN       NaN
# 1327           NaN            NaN            NaN       NaN       NaN
#
#       BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF  Bsmt Full Bath  \
# 616            0.0           0.0          0.0            0.0             NaN
# 1327           NaN           NaN          NaN            NaN             NaN
#
#       Bsmt Half Bath
# 616              NaN
# 1327             NaN

# %%
#This row has values to be imputed as well

# %%
#so there is still one odd NaN in BsmtFin Type 2
df_2  = df.iloc[: , 20:40]
df_2.isnull().sum().sort_values(ascending = False).head(8)
# Out:
# BsmtFin Type 2    55
# Bsmt Cond         54
# BsmtFin Type 1    54
# Bsmt Qual         54
# Bsmt Exposure     54
# Mas Vnr Type      22
# Mas Vnr Area      22
# Heating            0
# dtype: int64

# %%
df2_type2 = df_2.loc[(df_2['BsmtFin Type 2'].isna()) & (df_2["BsmtFin Type 1"].notna())]
df2_type2
# Out:
#      Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# 1147      Gable   CompShg      VinylSd      VinylSd      BrkFace
#
#       Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual Bsmt Cond  \
# 1147         296.0         Gd         TA      PConc        Gd        TA
#
#      Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  BsmtFin SF 2  \
# 1147            No            GLQ        1124.0            NaN         479.0
#
#       Bsmt Unf SF  Total Bsmt SF Heating Heating QC
# 1147       1603.0         3206.0    GasA         Ex

# %%
#If Bsmt Fin SF 1 and Bsmt Fin SF 2 are added together, it would equal Bsmt Unf SF
#And if Total Bsmt is divided by 2, it would equal Bsmt Unf SF
#As it seems this data is corrupted, the row will be deleted
df2_b_todel= list(df2_type2.index.values)
df2_b_todel
# Out:
# [1147]

# %%
#dropping the corrupted row
df.drop(df2_b_todel, inplace = True)

# %%
df_2  = df.iloc[: , 20:40]
df_2.isnull().sum().sort_values(ascending = False).head(8)
# Out:
# Bsmt Cond         54
# BsmtFin Type 1    54
# BsmtFin Type 2    54
# Bsmt Qual         54
# Bsmt Exposure     54
# Mas Vnr Type      22
# Mas Vnr Area      22
# Heating            0
# dtype: int64

# %%
#### Cleaning Masonry

# %%
df2_mas = df_2[["Mas Vnr Type","Mas Vnr Area"]]
df2_mas_type_nan = df2_mas[df2_mas["Mas Vnr Type"].isna()]
print(df2_mas_type_nan.shape)
df2_mas_area_nan = df2_mas[df2_mas["Mas Vnr Area"].isna()]
print(df2_mas_area_nan.shape)
# Out:
# (22, 2)
# (22, 2)

# %%
df2_mas_type_nan
# Out:
#      Mas Vnr Type  Mas Vnr Area
# 22            NaN           NaN
# 41            NaN           NaN
# 86            NaN           NaN
# 212           NaN           NaN
# 276           NaN           NaN
# 338           NaN           NaN
# 431           NaN           NaN
# 451           NaN           NaN
# 591           NaN           NaN
# 844           NaN           NaN
# 913           NaN           NaN
# 939           NaN           NaN
# 1025          NaN           NaN
# 1244          NaN           NaN
# 1306          NaN           NaN
# 1430          NaN           NaN
# 1434          NaN           NaN
# 1606          NaN           NaN
# 1699          NaN           NaN
# 1815          NaN           NaN
# 1820          NaN           NaN
# 1941          NaN           NaN

# %%
#There is no mismatch in data and no corrupted values.
#Type will be changed to none
#Area to 0

# %%
df_2_zero = ["Mas Vnr Area", "Bsmt Full Bath", "Bsmt Half Bath", "Bsmt Cond", "Bsmt Qual"]
replace_nan_with_zero (df_2_zero)

# %%
df_2_none = ["BsmtFin Type 2","BsmtFin Type 1","Bsmt Exposure", "Mas Vnr Type"]
replace_nan_with_none(df_2_none)

# %%
#check
df[df["BsmtFin Type 2"].isna()]
# Out:
# Empty DataFrame
# ...

# %%
#check
df[df["Mas Vnr Area"].isna()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# #### DF 2 Summary
# BsmtFin Type 2 filled with None
# Bsmt Cond filled with None
# BsmtFin Type 1 filled with None
# Bsmt Exposure filled with None
# Bsmt Qual filled with None
# Mas Vnr Type filled with None
# Mas Vnr Area filled with zero
# Rows 1456, 1547, 1997, 1147 dropped

# %% [markdown]
# #### DATAFRAME 3: COLUMNS 40 - 59

# %%
# Selecting the next 20 columns
df_3  = df.iloc[: , 40:60]
df_3.head()
# Out:
#   Central Air Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  \
# 0           Y      SBrkr         725         754                0
# 1           Y      SBrkr         913        1209                0
# 2           Y      SBrkr        1057           0                0
# 3           Y      SBrkr         744         700                0
# 4           Y      SBrkr         831         614                0
#
#    Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  \
# 0         1479             0.0             0.0          2          1
# 1         2122             1.0             0.0          2          1
# 2         1057             1.0             0.0          1          0
# 3         1444             0.0             0.0          2          1
# 4         1445             0.0             0.0          2          0
#
#    Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  \
# 0              3              1           Gd              6        Typ
# ...

# %%
df_3.isnull().sum().sort_values(ascending = False).head(8)
# Out:
# Fireplace Qu     999
# Garage Finish    114
# Garage Yr Blt    114
# Garage Type      113
# Electrical         0
# Fireplaces         0
# Functional         0
# TotRms AbvGrd      0
# dtype: int64

# %% [markdown]
# #### Cleaning Fireplaces

# %%
df3_fp = df_3[['Fireplace Qu','Fireplaces']]
df3_fp.head()
# Out:
#   Fireplace Qu  Fireplaces
# 0          NaN           0
# 1           TA           1
# 2          NaN           0
# 3          NaN           0
# 4          NaN           0

# %%
#There is no mismatch and corrupted data. As such, all NaN in fireplace qu will be replaced with "None"
df3_fp_corrupt = df3_fp.loc[(df3_fp['Fireplace Qu'].isna()) & (df3_fp["Fireplaces"] != 0)]
df3_fp_corrupt
# Out:
# Empty DataFrame
# Columns: [Fireplace Qu, Fireplaces]
# Index: []

# %% [markdown]
# #### Cleaning Garages

# %%
#As there are other garage variables in df_4, i will bring them in for checking
df3_garage = df[['Garage Finish','Garage Yr Blt',"Garage Type", "Garage Cars", "Garage Area", "Garage Qual", "Garage Cond"]]
df3_garage.head()
# Out:
#   Garage Finish  Garage Yr Blt Garage Type  Garage Cars  Garage Area  \
# 0           RFn         1976.0      Attchd          2.0        475.0
# 1           RFn         1997.0      Attchd          2.0        559.0
# 2           Unf         1953.0      Detchd          1.0        246.0
# 3           Fin         2007.0     BuiltIn          2.0        400.0
# 4           Unf         1957.0      Detchd          2.0        484.0
#
#   Garage Qual Garage Cond
# 0          TA          TA
# 1          TA          TA
# 2          TA          TA
# 3          TA          TA
# 4          TA          TA

# %%
df3_garage.isnull().sum().sort_values(ascending = False).head(9)
# Out:
# Garage Finish    114
# Garage Yr Blt    114
# Garage Qual      114
# Garage Cond      114
# Garage Type      113
# Garage Cars        1
# Garage Area        1
# dtype: int64

# %%
df3_gar_area = df3_garage.loc[(df3_garage['Garage Area'].isna())]
df3_gar_area
# Out:
#      Garage Finish  Garage Yr Blt Garage Type  Garage Cars  Garage Area  \
# 1712           NaN            NaN      Detchd          NaN          NaN
#
#      Garage Qual Garage Cond
# 1712         NaN         NaN

# %%
#Corrupted value. To drop row
gar_area_drop = list(df3_gar_area.index.values)
df.drop(gar_area_drop, inplace = True)

# %%
df3_garage = df[['Garage Finish','Garage Yr Blt',"Garage Type", "Garage Cars", "Garage Area", "Garage Qual", "Garage Cond"]]
df3_garage.isnull().sum().sort_values(ascending = False).head(9)
# Out:
# Garage Finish    113
# Garage Yr Blt    113
# Garage Type      113
# Garage Qual      113
# Garage Cond      113
# Garage Cars        0
# Garage Area        0
# dtype: int64

# %%
# checking for corrupted values
df3_gar_fin = df3_garage.loc[(df3_garage['Garage Finish'].isna()) & (df3_garage["Garage Yr Blt"].notna())]
df3_gar_fin
# Out:
# Empty DataFrame
# Columns: [Garage Finish, Garage Yr Blt, Garage Type, Garage Cars, Garage Area, Garage Qual, Garage Cond]
# Index: []

# %%
df3_gar_all_na = df3_garage.loc[(df3_garage['Garage Finish'].isna())]
df3_gar_all_na
# Out:
#      Garage Finish  Garage Yr Blt Garage Type  Garage Cars  Garage Area  \
# 28             NaN            NaN         NaN          0.0          0.0
# 53             NaN            NaN         NaN          0.0          0.0
# 65             NaN            NaN         NaN          0.0          0.0
# 79             NaN            NaN         NaN          0.0          0.0
# 101            NaN            NaN         NaN          0.0          0.0
# 103            NaN            NaN         NaN          0.0          0.0
# 114            NaN            NaN         NaN          0.0          0.0
# 120            NaN            NaN         NaN          0.0          0.0
# 134            NaN            NaN         NaN          0.0          0.0
# 136            NaN            NaN         NaN          0.0          0.0
# 139            NaN            NaN         NaN          0.0          0.0
# 162            NaN            NaN         NaN          0.0          0.0
# ...

# %%
df_3_zero = ["Garage Yr Blt", "Garage Cars", "Garage Area", "Fireplace Qu", "Garage Qual", "Garage Cond"]
replace_nan_with_zero (df_3_zero)

# %%
df_3_none = ["Garage Finish", "Garage Type"]
replace_nan_with_none(df_3_none)

# %%
#check
df[df["Garage Finish"].isna()]
# Out:
# Empty DataFrame
# ...

# %%
#check
df[df["Garage Yr Blt"].isna()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# #### DF 3 Summary
# "Garage Yr Blt", "Garage Cars", "Garage Area" filled with zero
# "Garage Finish", "Garage Type", "Garage Qual", "Garage Cond", "Fireplace Qu" filled with None
# Row 1712 dropped

# %% [markdown]
# ### DATAFRAME 4: COLUMNS 60 - 81

# %%
# Selecting the last 20 columns
df_4  = df.iloc[: , 60:81]
df_4.head()
# Out:
#    Garage Cars  Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0          2.0        475.0          TA          TA           Y             0
# 1          2.0        559.0          TA          TA           Y             0
# 2          1.0        246.0          TA          TA           Y             0
# 3          2.0        400.0          TA          TA           Y           100
# 4          2.0        484.0          TA          TA           N             0
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
#
# ...

# %%
df_4.isnull().sum().sort_values(ascending = False).head(8)
# Out:
# Pool QC         2039
# Misc Feature    1983
# Fence           1650
# Garage Cars        0
# Garage Area        0
# SalePrice          0
# Sale Type          0
# Yr Sold            0
# dtype: int64

# %%
#Pool QC has 99.4% missing values
#As such, it will be dropped
2039/2051
# Out:
# 0.9941491955143832

# %%
#Misc Feature has 96.6% missing values
#As such, it will be dropped
1983/2051
# Out:
# 0.9668454412481716

# %%
#Fence has 80.4% missing values
#As such, it will be dropped
1650/ 2051
# Out:
# 0.8044856167723062

# %%
df.drop(labels=["Pool QC", "Misc Feature", "Fence"], axis=1, inplace=True)

# %% [markdown]
# #### DF 4 Summary
# "Pool QC", "Misc Feature", "Fence" dropped

# %% [markdown]
# ## Dataframe Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2048 entries, 0 to 2050
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2048 non-null   int64
#  1   MS SubClass      2048 non-null   int64
#  2   MS Zoning        2048 non-null   object
#  3   Lot Frontage     2048 non-null   float64
#  4   Lot Area         2048 non-null   int64
#  5   Street           2048 non-null   object
#  6   Lot Shape        2048 non-null   object
#  7   Land Contour     2048 non-null   object
#  8   Utilities        2048 non-null   object
#  9   Lot Config       2048 non-null   object
#  10  Land Slope       2048 non-null   object
#  11  Neighborhood     2048 non-null   object
#  12  Condition 1      2048 non-null   object
#  13  Condition 2      2048 non-null   object
#  14  Bldg Type        2048 non-null   object
#  15  House Style      2048 non-null   object
# ...

# %%
col_name="SalePrice"
first_col = df.pop(col_name)

df.insert(75, col_name, first_col)

# %%
df_1  = df.iloc[: , 0:20]
df_2  = df.iloc[: , 20:40]
df_3  = df.iloc[: , 40:60]
df_4  = df.iloc[: , 60:]

# %%
df_1["SalePrice"] = df["SalePrice"]
df_2["SalePrice"] = df["SalePrice"]
df_3["SalePrice"] = df["SalePrice"]

# %% [markdown]
# ### Using correlation matrix to check for correlation to sale price

# %%
df1_corr = df_1.corr()
np.ones_like(df1_corr, dtype=np.bool)
mask = np.triu(np.ones_like(df1_corr, dtype=np.bool))
mask = mask[1:, :-1]
corr = df1_corr.iloc[1:,:-1].copy()
fig, ax = plt.subplots(figsize=(20,10)) 
title = 'DF 1\nColumns 0 - 19\n'.upper()
plt.title(title, loc='left')
sns.heatmap(corr, mask=mask, annot=True, vmin=-1, vmax=1, linewidth=0.3, square=True, cbar_kws={"shrink": .8}, cmap='coolwarm');
# Out:
# <ipython-input-73-67b1f89ba39f>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.ones_like(df1_corr, dtype=np.bool)
# <ipython-input-73-67b1f89ba39f>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df1_corr, dtype=np.bool))

# %% [markdown]
# From DF 1, the following will be removed as they have low correlation to saleprice:
#     - PID
#     - MS SubClass
#     - Overall Cond

# %%
df2_corr = df_2.corr()
np.ones_like(df2_corr, dtype=np.bool)
mask = np.triu(np.ones_like(df2_corr, dtype=np.bool))
mask = mask[1:, :-1]
corr = df2_corr.iloc[1:,:-1].copy()
fig, ax = plt.subplots(figsize=(20,10)) 
title = 'DF 2\nColumns 20 - 39\n'.upper()
plt.title(title, loc='left')
sns.heatmap(corr, mask=mask, annot=True, vmin=-1, vmax=1, linewidth=0.3, square=True, cbar_kws={"shrink": .8}, cmap='coolwarm');
# Out:
# <ipython-input-74-69baa6315309>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.ones_like(df2_corr, dtype=np.bool)
# <ipython-input-74-69baa6315309>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df2_corr, dtype=np.bool))

# %% [raw]
# For DF 2
#
# The following will be removed as it has low correlation scores:
#     - BsmtFin SF 2
#     - Bsmt Unf SF

# %%
df3_corr = df_3.corr()
np.ones_like(df3_corr, dtype=np.bool)
mask = np.triu(np.ones_like(df3_corr, dtype=np.bool))
mask = mask[1:, :-1]
corr = df3_corr.iloc[1:,:-1].copy()
fig, ax = plt.subplots(figsize=(20,10)) 
title = 'DF 3\nColumns 40 - 59\n'.upper()
plt.title(title, loc='left')
sns.heatmap(corr, mask=mask, annot=True, vmin=-1, vmax=1, linewidth=0.3, square=True, cbar_kws={"shrink": .8}, cmap='coolwarm');
# Out:
# <ipython-input-75-8d8789c61b18>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.ones_like(df3_corr, dtype=np.bool)
# <ipython-input-75-8d8789c61b18>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df3_corr, dtype=np.bool))

# %% [markdown]
# For DF 3
#
# The following will be removed as they have low correlation scores:
#     - Low Qual Fin SF
#     - Bsmt Half Bath
#     - Bedroom AbvGr
#     - Kitchen AbvGr

# %%
df4_corr = df_4.corr()
np.ones_like(df4_corr, dtype=np.bool)
mask = np.triu(np.ones_like(df4_corr, dtype=np.bool))
mask = mask[1:, :-1]
corr = df4_corr.iloc[1:,:-1].copy()
fig, ax = plt.subplots(figsize=(20,10)) 
title = 'DF 3\nColumns 60 - 80\n'.upper()
plt.title(title, loc='left')
sns.heatmap(corr, mask=mask, annot=True, vmin=-1, vmax=1, linewidth=0.3, square=True, cbar_kws={"shrink": .8}, cmap='coolwarm');
# Out:
# <ipython-input-76-8101f6531ab3>:2: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   np.ones_like(df4_corr, dtype=np.bool)
# <ipython-input-76-8101f6531ab3>:3: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   mask = np.triu(np.ones_like(df4_corr, dtype=np.bool))

# %% [markdown]
# ## EDA

# %%
#Most houses do not have a porch
#Can delete
df.hist(column = "Enclosed Porch")
# Out:
# array([[<AxesSubplot:title={'center':'Enclosed Porch'}>]], dtype=object)

# %%
#Only a few houses have a 3 season porch
#Can delete
df.hist(column = "3Ssn Porch")
# Out:
# array([[<AxesSubplot:title={'center':'3Ssn Porch'}>]], dtype=object)

# %%
#Only a few houses have a porched covered by screen
#Can delete
df.hist(column = "Screen Porch")
# Out:
# array([[<AxesSubplot:title={'center':'Screen Porch'}>]], dtype=object)

# %% [markdown]
# From the porch data, I can infer that most people in Ames do not care for a porch.
# As such, we do not need to care about porches when purchasing property.

# %%
#As expected, given the amount of missing data, most houses do not have a pool
df.hist(column = "Pool Area")
# Out:
# array([[<AxesSubplot:title={'center':'Pool Area'}>]], dtype=object)

# %%
#It can be seen that the size of the pool does not determine the price of the house.
#Even places with large pools sell for less that places without a pool
df.groupby('Pool Area')['SalePrice'].mean()
# Out:
# Pool Area
# 0      181356.29181
# 228    315000.00000
# 368    153000.00000
# 480    160000.00000
# 519    250000.00000
# 561    130000.00000
# 576    171000.00000
# 648    181000.00000
# 738    274970.00000
# 800    260000.00000
# Name: SalePrice, dtype: float64

# %%
# Almost all house have no miscellaneous property with value
df.hist(column = "Misc Val")
# Out:
# array([[<AxesSubplot:title={'center':'Misc Val'}>]], dtype=object)

# %%
# looking at outliers
df['Misc Val'].sort_values().tail(20)
# Out:
# 1302     1200
# 150      1200
# 1848     1300
# 1610     1500
# 155      2000
# 253      2000
# 52       2000
# 29       2000
# 631      2000
# 1759     2500
# 1967     2500
# 345      3000
# 263      3000
# 700      3500
# 1786     4500
# 380      4500
# 1225     6500
# 765      8300
# 304     12500
# 1885    17000
# Name: Misc Val, dtype: int64

# %%
df.loc[[765, 304, 1885]]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 765   533352075           90        RL          87.0     18890   Pave
# 304   526351010           20        RL          81.0     14267   Pave
# 1885  908154195           20        RL         128.0     39290   Pave
#
#      Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 765        IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 304        IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 1885       IR1          Bnk    AllPub     Inside        Gtl      Edwards
#
#      Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 765        Feedr        RRAe    Duplex      1.5Fin             5
# 304         Norm        Norm      1Fam      1Story             6
# 1885        Norm        Norm      1Fam      1Story            10
#
#       Overall Cond  Year Built  Year Remod/Add Roof Style Roof Matl  \
# ...

# %% [markdown]
# Rows 304 and 1885 can be deleted.
# They are major outliers and index 1885 has negative age, it was built after it was sold.

# %%
#dropping outliers for misc val
df.drop([304, 1885], inplace = True)

# %%
# Majority of property sold are during May to Jul
df.hist(column = "Mo Sold")
# Out:
# array([[<AxesSubplot:title={'center':'Mo Sold'}>]], dtype=object)

# %%
# The Financial Crisis happened during Dec 2007- Jun 2009
# It can be seen from the histogram that there was a slight dip in sales in the years of '08 and '09' as compared to '07
# However, it was still pretty much the same as 2006
# The low 2010 count is bcause test data extract was data drom 2010
df.hist(column = "Yr Sold")
# Out:
# array([[<AxesSubplot:title={'center':'Yr Sold'}>]], dtype=object)

# %%
# Most houses have finished SF area
df.hist(column = "Low Qual Fin SF")
# Out:
# array([[<AxesSubplot:title={'center':'Low Qual Fin SF'}>]], dtype=object)

# %%
df['Low Qual Fin SF'].sort_values().tail(20)
# Out:
# 1599     259
# 1026     312
# 1756     360
# 1961     362
# 382      371
# 1688     384
# 1234     390
# 1433     397
# 1640     436
# 2042     450
# 497      473
# 1563     479
# 1333     512
# 356      513
# 1419     514
# 858      515
# 320      528
# 1035     572
# 1239     697
# 828     1064
# Name: Low Qual Fin SF, dtype: int64

# %%
#This unit is very interesting as it has a huge garage and a large low qual SF area
#It is also 94 yrs old
#The basement is also largely untouched
#Given that it has alot of places with low / unfinished SF, it would cost alot to furnish the place
#Typically, this kind of property would not make for good rental, given the outlay required for renovation
#In anycase, since it is an outlier, it will be removed
df.loc[[828]]
# Out:
#            PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 828  535381040           50        RL          60.0     10410   Pave
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 828       Reg          Lvl    AllPub     Inside        Gtl      OldTown
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 828        Norm        Norm      1Fam      1.5Fin             4             5
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 828        1915            1950      Gable   CompShg      MetalSd
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 828      MetalSd         None           0.0         TA         TA     BrkTil
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 828        TA        TA            No            Unf           0.0
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# ...

# %%
#dropping outliers for loq qual area
df.drop([828], inplace = True)

# %%
# Most houses do not install half baths in the basement
# A half bath is basically a bathroom with a sink and toilet bowl, but no shower or bathtub
df.hist(column = "Bsmt Half Bath")
# Out:
# array([[<AxesSubplot:title={'center':'Bsmt Half Bath'}>]], dtype=object)

# %%
df['Bsmt Half Bath'].sort_values().tail(20)
# Out:
# 859     1.0
# 1612    1.0
# 1609    1.0
# 1607    1.0
# 613     1.0
# 1402    1.0
# 1391    1.0
# 1904    1.0
# 1393    1.0
# 135     1.0
# 1395    1.0
# 874     1.0
# 131     1.0
# 1114    1.0
# 605     1.0
# 1487    1.0
# 761     2.0
# 1280    2.0
# 1137    2.0
# 1519    2.0
# Name: Bsmt Half Bath, dtype: float64

# %%
#Can't say if they are outliers.
#As such they wont be removed.
df.loc[[761, 1280, 1137, 1519]]
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 761   532476050           80        RL         100.0     14330   Pave
# 1280  528228275          120        RL          53.0      3922   Pave
# 1137  908103320           90        RL          35.0      9400   Pave
# 1519  908103310           90        RL          38.0      7840   Pave
#
#      Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 761        IR1          Low    AllPub     Corner        Gtl      Veenker
# 1280       Reg          Lvl    AllPub     Inside        Gtl      Blmngtn
# 1137       IR1          Lvl    AllPub    CulDSac        Gtl      Edwards
# 1519       IR1          Lvl    AllPub    CulDSac        Gtl      Edwards
#
#      Condition 1 Condition 2 Bldg Type House Style  Overall Qual  \
# 761         Norm        Norm      1Fam        SLvl             7
# 1280        Norm        Norm    TwnhsE      1Story             7
# ...

# %%
#Most houses have 2-3 bedrooms above ground
#This can be the type of property that we want to look at as property investors as most people buy these kind of houses
df.hist(column = "Bedroom AbvGr")
# Out:
# array([[<AxesSubplot:title={'center':'Bedroom AbvGr'}>]], dtype=object)

# %%
#It would be good to look at houses with 1 kitchen at least.
#It seems most poeple do not want to buy houses with less than or more than 1 kitchen
df.hist(column = "Kitchen AbvGr")
# Out:
# array([[<AxesSubplot:title={'center':'Kitchen AbvGr'}>]], dtype=object)

# %%
#Property with 2 types of basement finishes do not seem popular
df.hist(column = "BsmtFin SF 2")
# Out:
# array([[<AxesSubplot:title={'center':'BsmtFin SF 2'}>]], dtype=object)

# %%
# 25% of property have finished basements
df.hist(column = "Bsmt Unf SF")
# Out:
# array([[<AxesSubplot:title={'center':'Bsmt Unf SF'}>]], dtype=object)

# %%
#The distribution of unfinished basements are spread out almost linearly
#The larger the unfinished basement, the less there are.
#Can't find out much more info
df["Bsmt Unf SF"].describe()
# Out:
# count    2045.000000
# mean      566.809291
# std       444.405425
# min         0.000000
# 25%       220.000000
# 50%       474.000000
# 75%       810.000000
# max      2336.000000
# Name: Bsmt Unf SF, dtype: float64

# %%
# Subclass 20 is most popular - 1-STORY 1946 & NEWER ALL STYLES
# Subclass 60 being the 2nd msot popular - 2-STORY 1946 & NEWER
# We should aim at these 2 types for higher chance for sales
df.hist(column = "MS SubClass", bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'MS SubClass'}>]], dtype=object)

# %%
# The overall condition is 5 - 6
# We do not need to be very picky about overall condition
df.hist(column = "Overall Cond", bins = 20)
# Out:
# array([[<AxesSubplot:title={'center':'Overall Cond'}>]], dtype=object)

# %%
#Most property are 20,000 sqft and below
df.hist(column = "Lot Area", bins = 20)
# Out:
# array([[<AxesSubplot:title={'center':'Lot Area'}>]], dtype=object)

# %%
#There are alot of lot area outliers
df['Lot Area'].sort_values().tail(30)
# Out:
# 125      24572
# 1432     25000
# 160      25339
# 1267     26073
# 12       26400
# 1335     27650
# 635      31250
# 1080     31770
# 337      32463
# 913      32668
# 1701     33120
# 24       34650
# 841      39104
# 108      39384
# 441      41600
# 1875     43500
# 1542     46589
# 616      47007
# 1167     47280
# 1726     50102
# 1571     50271
# 1964     51974
# 1843     53107
# 1052     53227
# 823      53504
# 745      57200
# 960      63887
# 1854     70761
# 694     115149
# 471     159000
# Name: Lot Area, dtype: int64

# %%
#dropping exessively large properties
df = df[df["Lot Area"] < 39000]

# %%
#Most lot areas are around 8000 - 10000 sqft
#This would be a good place to start when looking at property
df.hist(column = "Lot Area", bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'Lot Area'}>]], dtype=object)

# %%
df.groupby("Condition 1")["SalePrice"].count()
# Out:
# Condition 1
# Artery      69
# Feedr      106
# Norm      1748
# PosA        12
# PosN        26
# RRAe        21
# RRAn        36
# RRNe         3
# RRNn         6
# Name: SalePrice, dtype: int64

# %%
df.groupby("Condition 2")["SalePrice"].count()
# Out:
# Condition 2
# Artery       5
# Feedr       11
# Norm      2001
# PosA         3
# PosN         3
# RRAe         1
# RRAn         1
# RRNn         2
# Name: SalePrice, dtype: int64

# %%
#Most lot areas are around 8000 - 10000 sqft
#This would be a good place to start when looking at property
fig, ax = plt.subplots(figsize=(20,10))
sns.histplot(df["Gr Liv Area"])
# Out:
# <AxesSubplot:xlabel='Gr Liv Area', ylabel='Count'>

# %%
#Most lot areas are around 8000 - 10000 sqft
#This would be a good place to start when looking at property
df.hist(column = "Overall Qual", bins = 30)
# Out:
# array([[<AxesSubplot:title={'center':'Overall Qual'}>]], dtype=object)

# %%
df.groupby("Neighborhood")["SalePrice"].mean().sort_values()
# Out:
# Neighborhood
# MeadowV    100231.250000
# IDOTRR     100370.750000
# BrDale     103371.052632
# OldTown    125167.512346
# BrkSide    127663.000000
# Edwards    128800.114286
# SWISU      134758.875000
# Landmrk    137000.000000
# Sawyer     137181.909910
# NPkVill    140476.470588
# Blueste    144566.666667
# NAmes      145476.633117
# Mitchel    168121.604938
# SawyerW    187760.160920
# Greens     188666.666667
# Gilbert    190021.868421
# NWAmes     194619.022989
# Blmngtn    200417.681818
# CollgCr    202497.216667
# ClearCr    203606.285714
# Crawfor    205901.211268
# Somerst    227183.900000
# Timber     242602.195652
# Veenker    245356.250000
# GrnHill    280000.000000
# NoRidge    314470.595745
# StoneBr    316613.638889
# NridgHt    323152.272727
# Name: SalePrice, dtype: float64

# %%
#There is somewhat of a linear relationship, but of course with many outliers
fig, ax = plt.subplots(figsize=(20,10))
sns.scatterplot(df["Gr Liv Area"], df["SalePrice"])
ax.set_xlabel( "General Living Area", size = 20) 
ax.set_ylabel( "Sale Price", size = 20) 
ax.set_title( "Relationship", size = 30)
plt.legend()
plt.show()
# Out:
# /Users/as/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
df.head(2)
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0  533352170           60        RL         55.23     13517   Pave       IR1
# 1  531379050           60        RL         43.00     11492   Pave       IR1
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 1          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0        Norm      1Fam      2Story             6             8        1976
# 1        Norm      1Fam      2Story             7             5        1996
#
#    Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# 0            2005      Gable   CompShg      HdBoard      Plywood      BrkFace
# 1            1997      Gable   CompShg      VinylSd      VinylSd      BrkFace
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2027 entries, 0 to 2050
# Data columns (total 77 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2027 non-null   int64
#  1   MS SubClass      2027 non-null   int64
#  2   MS Zoning        2027 non-null   object
#  3   Lot Frontage     2027 non-null   float64
#  4   Lot Area         2027 non-null   int64
#  5   Street           2027 non-null   object
#  6   Lot Shape        2027 non-null   object
#  7   Land Contour     2027 non-null   object
#  8   Utilities        2027 non-null   object
#  9   Lot Config       2027 non-null   object
#  10  Land Slope       2027 non-null   object
#  11  Neighborhood     2027 non-null   object
#  12  Condition 1      2027 non-null   object
#  13  Condition 2      2027 non-null   object
#  14  Bldg Type        2027 non-null   object
#  15  House Style      2027 non-null   object
# ...

# %% [markdown]
# ## Test Data Cleaning

# %%
df_test = pd.read_csv("../data/test.csv")
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 878 entries, 0 to 877
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               878 non-null    int64
#  1   PID              878 non-null    int64
#  2   MS SubClass      878 non-null    int64
#  3   MS Zoning        878 non-null    object
#  4   Lot Frontage     718 non-null    float64
#  5   Lot Area         878 non-null    int64
#  6   Street           878 non-null    object
#  7   Alley            58 non-null     object
#  8   Lot Shape        878 non-null    object
#  9   Land Contour     878 non-null    object
#  10  Utilities        878 non-null    object
#  11  Lot Config       878 non-null    object
#  12  Land Slope       878 non-null    object
#  13  Neighborhood     878 non-null    object
#  14  Condition 1      878 non-null    object
#  15  Condition 2      878 non-null    object
#  16  Bldg Type        878 non-null    object
# ...

# %%
df_test["age"] = df_test["Yr Sold"] - df_test["Year Built"]

# %%
df_test.shape
# Out:
# (878, 81)

# %%
train_cols = list(df.columns)
test_cols = list(df_test.columns)

# %%
# check whether columns in train are in test
train_not_in_test = []
for i in test_cols:
    if i not in train_cols:
        train_not_in_test.append(i)
train_not_in_test
# Out:
# ['Id', 'Alley', 'Pool QC', 'Fence', 'Misc Feature']

# %%
df_test.drop(labels=train_not_in_test, axis=1, inplace=True)

# %%
print("df shape", df.shape)
print("df_test shape", df_test.shape)
# Out:
# df shape (2027, 77)
# df_test shape (878, 76)

# %%
df_test.isnull().sum().sort_values(ascending = False).head(20)
# Out:
# Fireplace Qu       422
# Lot Frontage       160
# Garage Cond         45
# Garage Yr Blt       45
# Garage Finish       45
# Garage Qual         45
# Garage Type         44
# BsmtFin Type 2      25
# BsmtFin Type 1      25
# Bsmt Exposure       25
# Bsmt Cond           25
# Bsmt Qual           25
# Mas Vnr Area         1
# Mas Vnr Type         1
# Electrical           1
# Paved Drive          0
# Pool Area            0
# Low Qual Fin SF      0
# Gr Liv Area          0
# Bsmt Full Bath       0
# dtype: int64

# %% [markdown]
# ### Fireplace Qu

# %%
test_fp = df_test[["Fireplaces","Fireplace Qu"]]
test_fp
# Out:
#      Fireplaces Fireplace Qu
# 0             0          NaN
# 1             0          NaN
# 2             1           Gd
# 3             0          NaN
# 4             2           Gd
# 5             0          NaN
# 6             0          NaN
# 7             0          NaN
# 8             0          NaN
# 9             2           Fa
# 10            0          NaN
# 11            0          NaN
# 12            1           TA
# 13            2           TA
# 14            1           Gd
# 15            1           Gd
# 16            2           Gd
# 17            0          NaN
# 18            2           TA
# 19            1           Gd
# 20            1           TA
# 21            0          NaN
# 22            1           Fa
# 23            2           TA
# 24            0          NaN
# 25            0          NaN
# 26            1           Gd
# 27            0          NaN
# 28            0          NaN
# 29            0          NaN
# 30            0          NaN
# ...

# %%
test_fp_fp_na = test_fp.loc[(test_fp['Fireplace Qu'].isna()) & (test_fp["Fireplaces"].notna())]
test_fp_fp_na.shape
# Out:
# (422, 2)

# %%
test_fp_na = test_fp.loc[(test_fp['Fireplace Qu'].isna())]
test_fp_na.shape
# Out:
# (422, 2)

# %%
# Fireplace Qu has no corrupted values. The column will be replaced with None

# %% [markdown]
# ### Lot Frontage

# %%
test_frontage = df_test[["Lot Frontage"]]
test_frontage.head(20)
# Out:
#     Lot Frontage
# 0           69.0
# 1            NaN
# 2           58.0
# 3           60.0
# 4            NaN
# 5           21.0
# 6           52.0
# 7            NaN
# 8           39.0
# 9           75.0
# 10          50.0
# 11          60.0
# 12          75.0
# 13           NaN
# 14          69.0
# 15          60.0
# 16          60.0
# 17          68.0
# 18          80.0
# 19         121.0

# %%
test_frontage[test_frontage["Lot Frontage"].isna()]
# Out:
#      Lot Frontage
# 1             NaN
# 4             NaN
# 7             NaN
# 13            NaN
# 20            NaN
# 21            NaN
# 23            NaN
# 26            NaN
# 30            NaN
# 37            NaN
# 41            NaN
# 57            NaN
# 59            NaN
# 63            NaN
# 65            NaN
# 66            NaN
# 69            NaN
# 72            NaN
# 73            NaN
# 74            NaN
# 75            NaN
# 78            NaN
# 87            NaN
# 88            NaN
# 90            NaN
# 100           NaN
# 106           NaN
# 107           NaN
# 111           NaN
# 114           NaN
# 123           NaN
# 143           NaN
# 147           NaN
# 155           NaN
# 159           NaN
# 174           NaN
# 181           NaN
# 182           NaN
# 186           NaN
# 187           NaN
# 195           NaN
# 204           NaN
# 210           NaN
# 216           NaN
# 219           NaN
# 224           NaN
# 226           NaN
# 235           NaN
# 241           NaN
# ...

# %%
#These will also be filled with 60, similar to train data
df_test['Lot Frontage'].fillna(60, inplace = True)

# %% [markdown]
# ### Garage

# %%
test_garage = df_test[["Garage Finish","Garage Cond", "Garage Qual", "Garage Yr Blt", "Garage Type"]]
test_garage
# Out:
#     Garage Finish Garage Cond Garage Qual  Garage Yr Blt Garage Type
# 0             Unf          Po          Po         1910.0      Detchd
# 1             Fin          TA          TA         1977.0      Attchd
# 2             RFn          TA          TA         2006.0      Attchd
# 3             Unf          TA          Fa         1935.0      Detchd
# 4             RFn          TA          TA         1963.0      Attchd
# 5             Unf          TA          TA         1972.0      Attchd
# 6             Unf          TA          TA         1959.0      Detchd
# 7             Unf          TA          TA         1978.0      Detchd
# 8             RFn          TA          TA         2004.0      Attchd
# 9             Unf          TA          TA         1980.0      Detchd
# 10            RFn          TA          TA         1991.0      Attchd
# 11            Unf          TA          TA         1993.0      Detchd
# 12            Unf          TA          TA         1954.0      Attchd
# ...

# %%
test_garage.isnull().sum().sort_values(ascending = False).head(9)
# Out:
# Garage Finish    45
# Garage Cond      45
# Garage Qual      45
# Garage Yr Blt    45
# Garage Type      44
# dtype: int64

# %%
test_gar_na = test_garage[test_garage["Garage Finish"].isna() & test_garage["Garage Type"].notna()]
test_gar_na
# Out:
#     Garage Finish Garage Cond Garage Qual  Garage Yr Blt Garage Type
# 764           NaN         NaN         NaN            NaN      Detchd

# %%
test_gar_na_list = list(test_gar_na.index.values)
test_gar_na_list
# Out:
# [764]

# %%
#Changing detached to None
df_test.at[test_gar_na_list, 'Garage Type'] = "None"

# %%
df_test_zero = ["Garage Yr Blt", "Garage Cars", "Garage Area", "Fireplace Qu", "Garage Qual", "Garage Cond"]
replace_nan_with_zero_test (df_3_zero)

# %%
df_test_none = ["Garage Type", "Garage Finish"]
replace_nan_with_none_test (df_test_none)

# %%
df_test.isnull().sum().sort_values(ascending = False).head(10)
# Out:
# BsmtFin Type 1    25
# BsmtFin Type 2    25
# Bsmt Qual         25
# Bsmt Cond         25
# Bsmt Exposure     25
# Mas Vnr Type       1
# Mas Vnr Area       1
# Electrical         1
# Full Bath          0
# Half Bath          0
# dtype: int64

# %% [markdown]
# ### Basement

# %%
test_bsmt = df_test[["BsmtFin Type 1","BsmtFin Type 2", "Bsmt Exposure", "Bsmt Cond", "Bsmt Qual"]]
test_bsmt.head()
# Out:
#   BsmtFin Type 1 BsmtFin Type 2 Bsmt Exposure Bsmt Cond Bsmt Qual
# 0            Unf            Unf            No        TA        Fa
# 1            Unf            Unf            No        TA        Gd
# 2            GLQ            Unf            Av        Gd        Gd
# 3            Unf            Unf            No        TA        TA
# 4            BLQ            Unf            No        TA        Gd

# %%
test_bsmt_null = test_bsmt[test_bsmt["BsmtFin Type 1"].isna()]
test_bsmt_null.shape
# Out:
# (25, 5)

# %%
df_test_bs_none = ["BsmtFin Type 1", "BsmtFin Type 2", "Bsmt Exposure"]
replace_nan_with_none_test (df_test_bs_none)

# %%
df_test_bs_zero = ["Bsmt Cond", "Bsmt Qual"]
replace_nan_with_zero_test (df_test_bs_zero)

# %%
df_test.isnull().sum().sort_values(ascending = False).head(10)
# Out:
# Electrical       1
# Mas Vnr Type     1
# Mas Vnr Area     1
# PID              0
# Half Bath        0
# Functional       0
# TotRms AbvGrd    0
# Kitchen Qual     0
# Kitchen AbvGr    0
# Bedroom AbvGr    0
# dtype: int64

# %% [markdown]
# #### Mas Vnr

# %%
test_mas = df_test[["Mas Vnr Area", "Mas Vnr Type"]]
test_mas.head()
# Out:
#    Mas Vnr Area Mas Vnr Type
# 0           0.0         None
# 1           0.0         None
# 2           0.0         None
# 3           0.0         None
# 4         247.0      BrkFace

# %%
test_mas_null = test_mas[test_mas["Mas Vnr Area"].isna()]
test_mas_null
# Out:
#      Mas Vnr Area Mas Vnr Type
# 865           NaN          NaN

# %%
df_test_mas_none = ["Mas Vnr Type"]
replace_nan_with_none_test (df_test_mas_none)

# %%
df_test_mas_none = ["Mas Vnr Area"]
replace_nan_with_zero_test (df_test_mas_none)

# %%
df_test.isnull().sum().sort_values(ascending = False).head()
# Out:
# Electrical    1
# PID           0
# Full Bath     0
# Fireplaces    0
# Functional    0
# dtype: int64

# %% [markdown]
# #### Electrical

# %%
test_elec = df_test[df_test["Electrical"].isna()]
test_elec.head()
# Out:
#            PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 634  916386080           80        RL          73.0      9735   Pave
#
#     Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 634       Reg          Lvl    AllPub     Inside        Gtl       Timber
#
#     Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 634        Norm        Norm      1Fam        SLvl             5             5
#
#      Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st  \
# 634        2006            2007      Gable   CompShg      VinylSd
#
#     Exterior 2nd Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation  \
# 634      VinylSd         None           0.0         TA         TA      PConc
#
#     Bsmt Qual Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1  \
# 634        Gd        TA            No            Unf             0
#
#     BsmtFin Type 2  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating  \
# ...

# %%
df_test_elect_none = ["Electrical"]
replace_nan_with_none_test (df_test_elect_none)

# %%
df_test.isnull().sum().sort_values(ascending = False).head()
# Out:
# PID              0
# Full Bath        0
# Fireplaces       0
# Functional       0
# TotRms AbvGrd    0
# dtype: int64

# %%
#Converting ordinals into numbers

# %%
df.head(2)
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0  533352170           60        RL         55.23     13517   Pave       IR1
# 1  531379050           60        RL         43.00     11492   Pave       IR1
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0          Lvl    AllPub    CulDSac        Gtl       Sawyer        RRAe
# 1          Lvl    AllPub    CulDSac        Gtl      SawyerW        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0        Norm      1Fam      2Story             6             8        1976
# 1        Norm      1Fam      2Story             7             5        1996
#
#    Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# 0            2005      Gable   CompShg      HdBoard      Plywood      BrkFace
# 1            1997      Gable   CompShg      VinylSd      VinylSd      BrkFace
#
# ...

# %%
df_test.head(2)
# Out:
#          PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Lot Shape  \
# 0  902301120          190        RM          69.0      9142   Pave       Reg
# 1  905108090           90        RL          60.0      9662   Pave       IR1
#
#   Land Contour Utilities Lot Config Land Slope Neighborhood Condition 1  \
# 0          Lvl    AllPub     Inside        Gtl      OldTown        Norm
# 1          Lvl    AllPub     Inside        Gtl       Sawyer        Norm
#
#   Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  Year Built  \
# 0        Norm    2fmCon      2Story             6             8        1910
# 1        Norm    Duplex      1Story             5             4        1977
#
#    Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd Mas Vnr Type  \
# 0            1950      Gable   CompShg      AsbShng      AsbShng         None
# 1            1977      Gable   CompShg      Plywood      Plywood         None
#
# ...

# %%
# Replacing ordinals for train df
df_details_ord = ['Kitchen Qual', 'Heating QC', 'Exter Qual', 'Exter Cond', 'Bsmt Qual', 'Bsmt Cond', 'Fireplace Qu', 'Garage Qual', 'Garage Cond']
for i in df_details_ord:
    df[i].replace("Ex", 5, inplace = True)
    df[i].replace("Gd", 4, inplace = True)
    df[i].replace("TA", 3, inplace = True)
    df[i].replace("Fa", 2, inplace = True)
    df[i].replace("Po", 1, inplace = True)

# %%
# # Replacing ordinals for test df
df_test_details_ord = ['Kitchen Qual', 'Heating QC', 'Exter Qual', 'Exter Cond', 'Bsmt Qual', 'Bsmt Cond', 'Fireplace Qu', 'Garage Qual', 'Garage Cond']
for j in df_test_details_ord:
    df_test[j].replace("Ex", 5, inplace = True)
    df_test[j].replace("Gd", 4, inplace = True)
    df_test[j].replace("TA", 3, inplace = True)
    df_test[j].replace("Fa", 2, inplace = True)
    df_test[j].replace("Po", 1, inplace = True)

# %% [markdown]
# ## Exporting cleaned dfs

# %%
df.to_csv('../data/train_cleaned_no_dummies.csv', index = False)

# %%
df_test.to_csv('../data/test_cleaned_no_dummies.csv', index = False)
